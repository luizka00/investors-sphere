# %% [markdown]
# Importing data from a website in a form of cvs file:

# %%
# Library for opening url and creating 
# requests
import urllib.request
import pandas as pd
# pretty-print python data structures
from pprint import pprint
# for parsing all the tables present 
# on the website
from html_table_parser.parser import HTMLTableParser
import matplotlib.pyplot as plt

# %% [markdown]
# function to read a website:

# %%
def get_content(url):

    #making request to the website
    request = urllib.request.Request(url=url)
    f = urllib.request.urlopen(request)

    #reading contents of the website
    return f.read()

# %%
si_content= get_content('https://strefainwestorow.pl/rekomendacje/lista-rekomendacji/wszystkie').decode('utf-8') #defining html content from this link

tabela = HTMLTableParser()

tabela.feed(si_content)

# %%
pprint(tabela.tables[0])
# Out:
# [['Spółka',
#   'Rodzaj',
#   'Cena aktualna',
#   'Cena docelowa',
#   'Potencjał zmiany ceny',
#   'Cena w dniu publ.',
#   'Instytucja',
#   'Data publ.',
#   'Raport'],
#  ['AILLERON (ALL)',
#   'Kupuj',
#   '17,62 zł',
#   '23,10 zł',
#   '31,10%',
#   '17,06 zł',
#   'Noble Securities',
#   '13.06.2024',
#   ''],
#  ['RAINBOW (RBW)*',
#   'Kupuj',
#   '112,20 zł',
#   '155,00 zł',
#   '38,15%',
#   '103,00 zł',
#   'BM Banku Pekao',
#   '12.06.2024',
#   ''],
#  ['SKARBIEC (SKH)*',
#   'Kupuj',
#   '22,90 zł',
#   '34,00 zł',
#   '48,47%',
#   '22,70 zł',
#   'BM Banku Pekao',
#   '11.06.2024',
#   ''],
#  ['INTERBUD (ITB)',
#   'Kupuj',
#   '3,02 zł',
#   '6,70 zł',
#   '121,85%',
#   '3,66 zł',
#   'East Value Research',
#   '11.06.2024',
#   ''],
#  ['ENTER (ENT)*',
#   'Kupuj',
#   '64,70 zł',
#   '77,50 zł',
#   '19,78%',
#   '61,00 zł',
#   'DM BDM',
#   '10.06.2024',
#   ''],
#  ['BIOMAXIMA (BMX)*',
#   'Kupuj',
#   '16,15 zł',
#   '22,90 zł',
#   '41,80%',
#   '14,55 zł',
#   'DM BDM',
#   '05.06.2024',
#   ''],
#  ['XTPL (XTP)',
#   'Kupuj',
#   '128,00 zł',
#   '167,00 zł',
#   '30,47%',
#   '126,20 zł',
#   'Trigon DM',
#   '03.06.2024',
#   ''],
#  ['STALPROFI (STF)*',
#   'Kupuj',
#   '9,16 zł',
#   '10,64 zł',
#   '16,16%',
#   '8,90 zł',
#   'BM Banku Pekao',
#   '03.06.2024',
#   ''],
#  ['PHOTON (PEN)*',
#   'Wycena',
#   '7,70 zł',
#   '6,82 zł',
#   '-11,43%',
#   '7,70 zł',
#   'Noble Securities',
#   '31.05.2024',
#   ''],
#  ['NOVAVISGR (NVG)',
#   'Kupuj',
#   '2,37 zł',
#   '4,00 zł',
#   '68,78%',
#   '2,07 zł',
#   'East Value Research',
#   '31.05.2024',
#   ''],
#  ['ENEA (ENA)',
#   'Trzymaj',
#   '9,55 zł',
#   '11,63 zł',
#   '21,78%',
#   '10,24 zł',
#   'Trigon DM',
#   '29.05.2024',
#   ''],
#  ['MOBRUK (MBR)',
#   'Akumuluj',
#   '310,50 zł',
#   '375,80 zł',
#   '21,03%',
#   '318,50 zł',
#   'Noble Securities',
#   '28.05.2024',
#   ''],
#  ['MLPGROUP (MLG)*',
#   'Kupuj',
#   '82,00 zł',
#   '110,00 zł',
#   '34,15%',
#   '80,00 zł',
#   'BM PKO BP',
#   '28.05.2024',
#   ''],
#  ['11BIT (11B)',
#   'Kupuj',
#   '633,00 zł',
#   '952,60 zł',
#   '50,49%',
#   '585,00 zł',
#   'Noble Securities',
#   '27.05.2024',
#   ''],
#  ['RYVU (RVU)',
#   'Trzymaj',
#   '51,50 zł',
#   '75,50 zł',
#   '46,60%',
#   '53,40 zł',
#   'Noble Securities',
#   '24.05.2024',
#   ''],
#  ['ATENDE (ATD)*',
#   'Kupuj',
#   '2,97 zł',
#   '3,70 zł',
#   '24,58%',
#   '2,90 zł',
#   'BM Banku Pekao',
#   '24.05.2024',
#   ''],
#  ['COMP (CMP)',
#   'Kupuj',
#   '96,20 zł',
#   '132,00 zł',
#   '37,21%',
#   '110,00 zł',
#   'DM BOŚ',
#   '24.05.2024',
#   ''],
#  ['SUNEX (SNX)*',
#   'Kupuj',
#   '10,18 zł',
#   '12,37 zł',
#   '21,51%',
#   '10,52 zł',
#   'Ipopema Securities',
#   '24.05.2024',
#   ''],
#  ['TSGAMES (TEN)',
#   'Kupuj',
#   '82,00 zł',
#   '118,00 zł',
#   '43,90%',
#   '93,80 zł',
#   'DM BDM',
#   '22.05.2024',
#   ''],
#  ['KINOPOL (KPL)*',
#   'Kupuj',
#   '17,25 zł',
#   '20,05 zł',
#   '16,23%',
#   '14,85 zł',
#   'DM BDM',
#   '21.05.2024',
#   ''],
#  ['TORPOL (TOR)',
#   'Trzymaj',
#   '34,75 zł',
#   '35,00 zł',
#   '0,72%',
#   '35,25 zł',
#   'Noble Securities',
#   '21.05.2024',
#   ''],
#  ['TAURONPE (TPE)',
#   'Kupuj',
#   '3,85 zł',
#   '3,94 zł',
#   '2,34%',
#   '3,93 zł',
#   'Trigon DM',
#   '20.05.2024',
#   ''],
#  ['RELPOL (RLP)*',
#   'Trzymaj',
#   '5,92 zł',
#   '6,25 zł',
#   '5,57%',
#   '6,16 zł',
#   'DM BDM',
#   '20.05.2024',
#   ''],
#  ['CCC (CCC)',
#   'Kupuj',
#   '122,50 zł',
#   '160,00 zł',
#   '30,61%',
#   '133,20 zł',
#   'Trigon DM',
#   '20.05.2024',
#   ''],
#  ['PGE (PGE)',
#   'Kupuj',
#   '6,70 zł',
#   '8,90 zł',
#   '32,84%',
#   '7,74 zł',
#   'Trigon DM',
#   '20.05.2024',
#   ''],
#  ['VOXEL (VOX)',
#   'Kupuj',
#   '90,00 zł',
#   '106,60 zł',
#   '18,44%',
#   '92,00 zł',
#   'DM BDM',
#   '20.05.2024',
#   ''],
#  ['ELEKTROTI (ELT)*',
#   'Akumuluj',
#   '30,60 zł',
#   '31,00 zł',
#   '1,31%',
#   '27,85 zł',
#   'DM BDM',
#   '20.05.2024',
#   ''],
#  ['ELQ (ELQ)',
#   'Kupuj',
#   '3,00 zł',
#   '3,90 zł',
#   '30,00%',
#   '3,01 zł',
#   'East Value Research',
#   '20.05.2024',
#   ''],
#  ['PEPCO (PCO)',
#   'Trzymaj',
#   '23,10 zł',
#   '21,90 zł',
#   '-5,19%',
#   '21,23 zł',
#   'Noble Securities',
#   '17.05.2024',
#   ''],
#  ['ACTION (ACT)*',
#   'Kupuj',
#   '20,00 zł',
#   '25,00 zł',
#   '25,00%',
#   '20,35 zł',
#   'DM BOŚ',
#   '17.05.2024',
#   ''],
#  ['GRUPAAZOTY (ATT)',
#   'Sprzedaj',
#   '21,52 zł',
#   '20,00 zł',
#   '-7,06%',
#   '24,64 zł',
#   'DM BOŚ',
#   '17.05.2024',
#   ''],
#  ['TORPOL (TOR)',
#   'Kupuj',
#   '34,75 zł',
#   '35,00 zł',
#   '0,72%',
#   '32,10 zł',
#   'Noble Securities',
#   '15.05.2024',
#   ''],
#  ['RAINBOW (RBW)',
#   'Kupuj',
#   '112,20 zł',
#   '136,60 zł',
#   '21,75%',
#   '107,00 zł',
#   'East Value Research',
#   '14.05.2024',
#   ''],
#  ['VOTUM (VOT)*',
#   'Kupuj',
#   '35,70 zł',
#   '66,90 zł',
#   '87,39%',
#   '43,65 zł',
#   'DM BOŚ',
#   '13.05.2024',
#   ''],
#  ['CYFRPLSAT (CPS)',
#   'Kupuj',
#   '11,89 zł',
#   '13,39 zł',
#   '12,62%',
#   '11,47 zł',
#   'DM BDM',
#   '10.05.2024',
#   ''],
#  ['RAINBOW (RBW)*',
#   'Kupuj',
#   '112,20 zł',
#   '120,00 zł',
#   '6,95%',
#   '94,90 zł',
#   'BM Banku Pekao',
#   '10.05.2024',
#   ''],
#  ['OPONEO.PL (OPN)*',
#   'Trzymaj',
#   '78,40 zł',
#   '63,50 zł',
#   '-19,01%',
#   '61,00 zł',
#   'BM PKO BP',
#   '10.05.2024',
#   ''],
#  ['UNIBEP (UNI)*',
#   'Wycena',
#   '9,32 zł',
#   '12,00 zł',
#   '28,76%',
#   '9,64 zł',
#   'Noble Securities',
#   '09.05.2024',
#   ''],
#  ['QUERCUS (QRS)*',
#   'Kupuj',
#   '6,02 zł',
#   '7,50 zł',
#   '24,58%',
#   '6,58 zł',
#   'BM Banku Pekao',
#   '09.05.2024',
#   ''],
#  ['ARTIFEX (ART)*',
#   'Trzymaj',
#   '22,10 zł',
#   '26,00 zł',
#   '17,65%',
#   '26,50 zł',
#   'DM BDM',
#   '08.05.2024',
#   ''],
#  ['IMS (IMS)*',
#   'Akumuluj',
#   '4,54 zł',
#   '5,00 zł',
#   '10,13%',
#   '4,36 zł',
#   'Millennium DM',
#   '08.05.2024',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 680,00 zł',
#   '23 300,00 zł',
#   '39,69%',
#   '16 530,00 zł',
#   'BM mBank',
#   '07.05.2024',
#   ''],
#  ['HANDLOWY (BHW)',
#   'Sprzedaj',
#   '105,00 zł',
#   '107,00 zł',
#   '1,90%',
#   '111,00 zł',
#   'BM mBank',
#   '07.05.2024',
#   ''],
#  ['ABPL (ABE)',
#   'Kupuj',
#   '101,00 zł',
#   '96,60 zł',
#   '-4,36%',
#   '89,80 zł',
#   'DM BOŚ',
#   '07.05.2024',
#   ''],
#  ['INTERCARS (CAR)',
#   'Trzymaj',
#   '540,00 zł',
#   '525,00 zł',
#   '-2,78%',
#   '539,00 zł',
#   'DM BOŚ',
#   '07.05.2024',
#   ''],
#  ['WARIMPEX (WXF)',
#   'Wycena',
#   '3,78 zł',
#   '9,49 zł',
#   '151,06%',
#   '3,72 zł',
#   'East Value Research',
#   '07.05.2024',
#   ''],
#  ['SONEL (SON)*',
#   'Wycena',
#   '17,85 zł',
#   '15,78 zł',
#   '-11,60%',
#   '14,90 zł',
#   'Noble Securities',
#   '06.05.2024',
#   ''],
#  ['SELVITA (SLV)',
#   'Trzymaj',
#   '63,70 zł',
#   '62,70 zł',
#   '-1,57%',
#   '70,60 zł',
#   'DM BOŚ',
#   '06.05.2024',
#   ''],
#  ['PGE (PGE)',
#   'Sprzedaj',
#   '6,70 zł',
#   '5,60 zł',
#   '-16,42%',
#   '6,18 zł',
#   'DM BOŚ',
#   '05.05.2024',
#   ''],
#  ['TAURONPE (TPE)',
#   'Sprzedaj',
#   '3,85 zł',
#   '2,60 zł',
#   '-32,47%',
#   '2,93 zł',
#   'DM BOŚ',
#   '05.05.2024',
#   ''],
#  ['ASBIS (ASB)',
#   'Kupuj',
#   '24,94 zł',
#   '38,60 zł',
#   '54,77%',
#   '24,60 zł',
#   'DM BOŚ',
#   '05.05.2024',
#   ''],
#  ['DINOPL (DNP)',
#   'Trzymaj',
#   '398,10 zł',
#   '382,50 zł',
#   '-3,92%',
#   '386,70 zł',
#   'DM BOŚ',
#   '05.05.2024',
#   ''],
#  ['TORPOL (TOR)',
#   'Akumuluj',
#   '34,75 zł',
#   '35,60 zł',
#   '2,45%',
#   '31,60 zł',
#   'DM BDM',
#   '02.05.2024',
#   ''],
#  ['CLOUD (CLD)*',
#   'Trzymaj',
#   '73,00 zł',
#   '75,00 zł',
#   '2,74%',
#   '70,60 zł',
#   'DM BOŚ',
#   '30.04.2024',
#   ''],
#  ['STALPROFI (STF)*',
#   'Kupuj',
#   '9,16 zł',
#   '9,85 zł',
#   '7,53%',
#   '8,26 zł',
#   'BM Banku Pekao',
#   '30.04.2024',
#   ''],
#  ['VOXEL (VOX)*',
#   'Kupuj',
#   '90,00 zł',
#   '103,00 zł',
#   '14,44%',
#   '92,20 zł',
#   'DM BOŚ',
#   '29.04.2024',
#   ''],
#  ['MABION (MAB)*',
#   'Wycena',
#   '17,26 zł',
#   '19,00 zł',
#   '10,08%',
#   '16,24 zł',
#   'Noble Securities',
#   '29.04.2024',
#   ''],
#  ['FORTE (FTE)',
#   'Trzymaj',
#   '21,60 zł',
#   '21,10 zł',
#   '-2,31%',
#   '23,00 zł',
#   'DM BOŚ',
#   '29.04.2024',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 680,00 zł',
#   '21 047,00 zł',
#   '26,18%',
#   '15 550,00 zł',
#   'DM BOŚ',
#   '29.04.2024',
#   ''],
#  ['CCC (CCC)',
#   'Kupuj',
#   '122,50 zł',
#   '108,80 zł',
#   '-11,18%',
#   '87,50 zł',
#   'DM BOŚ',
#   '29.04.2024',
#   ''],
#  ['ARCHICOM (ARH)',
#   'Kupuj',
#   '33,00 zł',
#   '40,00 zł',
#   '21,21%',
#   '34,00 zł',
#   'Trigon DM',
#   '25.04.2024',
#   ''],
#  ['DADELO (DAD)*',
#   'Kupuj',
#   '20,10 zł',
#   '23,00 zł',
#   '14,43%',
#   '17,25 zł',
#   'Trigon DM',
#   '25.04.2024',
#   ''],
#  ['ECHO (ECH)',
#   'Kupuj',
#   '4,62 zł',
#   '6,00 zł',
#   '29,87%',
#   '4,91 zł',
#   'Trigon DM',
#   '25.04.2024',
#   ''],
#  ['AILLERON (ALL)*',
#   'Kupuj',
#   '17,62 zł',
#   '25,00 zł',
#   '41,88%',
#   '15,70 zł',
#   'Trigon DM',
#   '25.04.2024',
#   ''],
#  ['FABRITY (FAB)*',
#   'Trzymaj',
#   '37,50 zł',
#   '39,00 zł',
#   '4,00%',
#   '36,80 zł',
#   'Trigon DM',
#   '25.04.2024',
#   ''],
#  ['MFO (MFO)*',
#   'Kupuj',
#   '31,30 zł',
#   '49,30 zł',
#   '57,51%',
#   '33,60 zł',
#   'Trigon DM',
#   '25.04.2024',
#   ''],
#  ['SELENAFM (SEL)*',
#   'Kupuj',
#   '34,50 zł',
#   '46,40 zł',
#   '34,49%',
#   '32,60 zł',
#   'Trigon DM',
#   '25.04.2024',
#   ''],
#  ['PZU (PZU)',
#   'Kupuj',
#   '48,34 zł',
#   '58,30 zł',
#   '20,60%',
#   '50,68 zł',
#   'Trigon DM',
#   '22.04.2024',
#   ''],
#  ['ZUE (ZUE)*',
#   'Trzymaj',
#   '10,75 zł',
#   '11,10 zł',
#   '3,26%',
#   '10,90 zł',
#   'DM BDM',
#   '22.04.2024',
#   ''],
#  ['CCC (CCC)',
#   'Kupuj',
#   '122,50 zł',
#   '120,00 zł',
#   '-2,04%',
#   '82,60 zł',
#   'Trigon DM',
#   '22.04.2024',
#   ''],
#  ['ATMGRUPA (ATG)*',
#   'Kupuj',
#   '4,15 zł',
#   '4,91 zł',
#   '18,31%',
#   '3,20 zł',
#   'DM BDM',
#   '22.04.2024',
#   ''],
#  ['BIOTON (BIO)*',
#   'Wycena',
#   '3,50 zł',
#   '4,46 zł',
#   '27,43%',
#   '3,50 zł',
#   'Noble Securities',
#   '18.04.2024',
#   ''],
#  ['KGHM (KGH)',
#   'Kupuj',
#   '141,45 zł',
#   '185,00 zł',
#   '30,79%',
#   '142,40 zł',
#   'DM BOŚ',
#   '18.04.2024',
#   ''],
#  ['ORANGEPL (OPL)',
#   'Kupuj',
#   '8,00 zł',
#   '9,30 zł',
#   '16,28%',
#   '7,78 zł',
#   'DM BOŚ',
#   '17.04.2024',
#   ''],
#  ['BOGDANKA (LWB)',
#   'Sprzedaj',
#   '29,42 zł',
#   '25,00 zł',
#   '-15,02%',
#   '32,72 zł',
#   'DM BOŚ',
#   '17.04.2024',
#   ''],
#  ['CAPTORTX (CTX)',
#   'Kupuj',
#   '79,00 zł',
#   '131,10 zł',
#   '65,95%',
#   '79,00 zł',
#   'Noble Securities',
#   '16.04.2024',
#   ''],
#  ['TSGAMES (TEN)',
#   'Trzymaj',
#   '82,00 zł',
#   '106,00 zł',
#   '29,27%',
#   '96,10 zł',
#   'DM BOŚ',
#   '15.04.2024',
#   ''],
#  ['SYGNITY (SGN)*',
#   'Sprzedaj',
#   '64,00 zł',
#   '35,80 zł',
#   '-44,06%',
#   '64,00 zł',
#   'BM mBank',
#   '15.04.2024',
#   ''],
#  ['HUUUGE (HUG)',
#   'Kupuj',
#   '22,85 zł',
#   '35,20 zł',
#   '54,05%',
#   '26,40 zł',
#   'DM BDM',
#   '15.04.2024',
#   ''],
#  ['JSW (JSW)',
#   'Sprzedaj',
#   '29,10 zł',
#   '30,00 zł',
#   '3,09%',
#   '35,34 zł',
#   'DM BOŚ',
#   '15.04.2024',
#   ''],
#  ['ATENDE (ATD)*',
#   'Kupuj',
#   '2,97 zł',
#   '4,10 zł',
#   '38,05%',
#   '2,93 zł',
#   'BM Banku Pekao',
#   '15.04.2024',
#   ''],
#  ['IFIRMA (IFI)*',
#   'Neutralna',
#   '23,20 zł',
#   '21,40 zł',
#   '-7,76%',
#   '22,20 zł',
#   'Millennium DM',
#   '12.04.2024',
#   ''],
#  ['TOYA (TOA)*',
#   'Wycena',
#   '7,92 zł',
#   '11,50 zł',
#   '45,20%',
#   '7,14 zł',
#   'Noble Securities',
#   '11.04.2024',
#   ''],
#  ['ORANGEPL (OPL)',
#   'Akumuluj',
#   '8,00 zł',
#   '9,00 zł',
#   '12,53%',
#   '8,02 zł',
#   'DM BDM',
#   '10.04.2024',
#   ''],
#  ['BRAND24 (B24)*',
#   'Wycena',
#   '46,20 zł',
#   '56,20 zł',
#   '21,65%',
#   '48,80 zł',
#   'DM BOŚ',
#   '09.04.2024',
#   ''],
#  ['VOXEL (VOX)*',
#   'Kupuj',
#   '90,00 zł',
#   '97,70 zł',
#   '8,56%',
#   '93,20 zł',
#   'DM BOŚ',
#   '08.04.2024',
#   ''],
#  ['MCI (MCI)*',
#   'Wycena',
#   '25,50 zł',
#   '40,70 zł',
#   '59,61%',
#   '25,10 zł',
#   'Noble Securities',
#   '05.04.2024',
#   ''],
#  ['TORPOL (TOR)',
#   'Redukuj',
#   '34,75 zł',
#   '35,50 zł',
#   '2,16%',
#   '35,00 zł',
#   'Noble Securities',
#   '03.04.2024',
#   ''],
#  ['BUDIMEX (BDX)',
#   'Sprzedaj',
#   '672,50 zł',
#   '630,00 zł',
#   '-6,32%',
#   '700,00 zł',
#   'Trigon DM',
#   '02.04.2024',
#   ''],
#  ['ASSECOSEE (ASE)',
#   'Trzymaj',
#   '49,90 zł',
#   '55,00 zł',
#   '10,22%',
#   '50,00 zł',
#   'DM BOŚ',
#   '28.03.2024',
#   ''],
#  ['ASSECOBS (ABS)',
#   'Trzymaj',
#   '56,00 zł',
#   '58,00 zł',
#   '3,57%',
#   '51,80 zł',
#   'DM BOŚ',
#   '28.03.2024',
#   ''],
#  ['FERRO (FRO)*',
#   'Kupuj',
#   '37,70 zł',
#   '39,30 zł',
#   '4,24%',
#   '33,50 zł',
#   'DM BOŚ',
#   '28.03.2024',
#   ''],
#  ['ASBIS (ASB)',
#   'Wycena',
#   '24,94 zł',
#   '61,00 zł',
#   '144,59%',
#   '24,80 zł',
#   'Argus Research',
#   '27.03.2024',
#   ''],
#  ['SEKO (SEK)*',
#   'Wycena',
#   '11,85 zł',
#   '18,90 zł',
#   '59,49%',
#   '12,90 zł',
#   'DM BOŚ',
#   '27.03.2024',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 680,00 zł',
#   '20 000,00 zł',
#   '19,90%',
#   '13 660,00 zł',
#   'Trigon DM',
#   '26.03.2024',
#   ''],
#  ['MURAPOL (MUR)',
#   'Kupuj',
#   '38,00 zł',
#   '50,00 zł',
#   '31,58%',
#   '41,37 zł',
#   'Trigon DM',
#   '25.03.2024',
#   ''],
#  ['DINOPL (DNP)',
#   'Akumuluj',
#   '398,10 zł',
#   '445,10 zł',
#   '11,81%',
#   '415,00 zł',
#   'Noble Securities',
#   '22.03.2024',
#   ''],
#  ['EUROCASH (EUR)',
#   'Trzymaj',
#   '12,62 zł',
#   '15,70 zł',
#   '24,41%',
#   '14,71 zł',
#   'Noble Securities',
#   '22.03.2024',
#   ''],
#  ['MARVIPOL (MVP)*',
#   'Kupuj',
#   '6,70 zł',
#   '11,15 zł',
#   '66,42%',
#   '8,26 zł',
#   'Ipopema Securities',
#   '20.03.2024',
#   ''],
#  ['AMBRA (AMB)*',
#   'Kupuj',
#   '27,70 zł',
#   '32,20 zł',
#   '16,25%',
#   '27,60 zł',
#   'Millennium DM',
#   '18.03.2024',
#   ''],
#  ['RAINBOW (RBW)',
#   'Kupuj',
#   '112,20 zł',
#   '105,00 zł',
#   '-6,42%',
#   '76,40 zł',
#   'Trigon DM',
#   '14.03.2024',
#   ''],
#  ['TORPOL (TOR)',
#   'Kupuj',
#   '34,75 zł',
#   '45,00 zł',
#   '29,50%',
#   '34,50 zł',
#   'BM Banku Pekao',
#   '14.03.2024',
#   ''],
#  ['SYNEKTIK (SNT)',
#   'Kupuj',
#   '141,40 zł',
#   '180,60 zł',
#   '27,72%',
#   '127,00 zł',
#   'Trigon DM',
#   '11.03.2024',
#   ''],
#  ['CDPROJEKT (CDR)',
#   'Kupuj',
#   '133,80 zł',
#   '192,80 zł',
#   '44,10%',
#   '107,75 zł',
#   'Noble Securities',
#   '08.03.2024',
#   ''],
#  ['CLNPHARMA (CLN)',
#   'Kupuj',
#   '15,42 zł',
#   '25,50 zł',
#   '65,37%',
#   '14,80 zł',
#   'Noble Securities',
#   '08.03.2024',
#   ''],
#  ['SNIEZKA (SKA)',
#   'Kupuj',
#   '85,00 zł',
#   '93,10 zł',
#   '9,53%',
#   '84,80 zł',
#   'DM BDM',
#   '08.03.2024',
#   ''],
#  ['MERCOR (MCR)*',
#   'Trzymaj',
#   '24,00 zł',
#   '26,40 zł',
#   '10,00%',
#   '23,20 zł',
#   'BM Banku Pekao',
#   '07.03.2024',
#   ''],
#  ['RAINBOW (RBW)',
#   'Kupuj',
#   '112,20 zł',
#   '92,40 zł',
#   '-17,65%',
#   '72,60 zł',
#   'East Value Research',
#   '06.03.2024',
#   ''],
#  ['CREEPYJAR (CRJ)',
#   'Kupuj',
#   '515,00 zł',
#   '760,00 zł',
#   '47,57%',
#   '580,00 zł',
#   'DM BDM',
#   '05.03.2024',
#   ''],
#  ['NOVAVISGR (NVG)*',
#   'Akumuluj',
#   '2,37 zł',
#   '3,12 zł',
#   '31,65%',
#   '2,63 zł',
#   'Erste',
#   '29.02.2024',
#   ''],
#  ['SYNEKTIK (SNT)',
#   'Kupuj',
#   '141,40 zł',
#   '138,10 zł',
#   '-2,33%',
#   '117,50 zł',
#   'East Value Research',
#   '29.02.2024',
#   ''],
#  ['NOCTILUCA (NCL)',
#   'Wycena',
#   '95,80 zł',
#   '208,90 zł',
#   '118,06%',
#   '106,00 zł',
#   'East Value Research',
#   '23.02.2024',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 680,00 zł',
#   '19 282,00 zł',
#   '15,60%',
#   '17 130,00 zł',
#   'Noble Securities',
#   '21.02.2024',
#   ''],
#  ['XTB (XTB)',
#   'Kupuj',
#   '66,56 zł',
#   '47,95 zł',
#   '-27,96%',
#   '47,22 zł',
#   'BM mBank',
#   '20.02.2024',
#   ''],
#  ['CDPROJEKT (CDR)',
#   'Redukuj',
#   '133,80 zł',
#   '102,00 zł',
#   '-23,77%',
#   '114,50 zł',
#   'DM BDM',
#   '19.02.2024',
#   ''],
#  ['VIGOPHOTN (VGO)*',
#   'Kupuj',
#   '510,00 zł',
#   '600,00 zł',
#   '17,65%',
#   '484,00 zł',
#   'Ipopema Securities',
#   '19.02.2024',
#   ''],
#  ['ELQ (ELQ)',
#   'Kupuj',
#   '3,00 zł',
#   '4,80 zł',
#   '60,00%',
#   '2,40 zł',
#   'East Value Research',
#   '19.02.2024',
#   ''],
#  ['SKARBIEC (SKH)*',
#   'Kupuj',
#   '22,90 zł',
#   '33,00 zł',
#   '44,10%',
#   '23,60 zł',
#   'BM Banku Pekao',
#   '16.02.2024',
#   ''],
#  ['QUERCUS (QRS)*',
#   'Kupuj',
#   '6,02 zł',
#   '6,70 zł',
#   '11,30%',
#   '5,80 zł',
#   'BM Banku Pekao',
#   '16.02.2024',
#   ''],
#  ['PGE (PGE)',
#   'Sprzedaj',
#   '6,70 zł',
#   '7,20 zł',
#   '7,46%',
#   '8,42 zł',
#   'DM BOŚ',
#   '15.02.2024',
#   ''],
#  ['VOXEL (VOX)*',
#   'Kupuj',
#   '90,00 zł',
#   '97,70 zł',
#   '8,56%',
#   '88,60 zł',
#   'DM BOŚ',
#   '14.02.2024',
#   ''],
#  ['UNIMOT (UNT)',
#   'Kupuj',
#   '130,80 zł',
#   '160,00 zł',
#   '22,32%',
#   '131,60 zł',
#   'DM BOŚ',
#   '13.02.2024',
#   ''],
#  ['PKNORLEN (PKN)',
#   'Kupuj',
#   '63,45 zł',
#   '90,00 zł',
#   '41,84%',
#   '65,67 zł',
#   'DM BOŚ',
#   '09.02.2024',
#   ''],
#  ['MIRACULUM (MIR)*',
#   'Trzymaj',
#   '1,15 zł',
#   '1,35 zł',
#   '17,39%',
#   '1,36 zł',
#   'Ipopema Securities',
#   '09.02.2024',
#   ''],
#  ['NOVAVISGR (NVG)',
#   'Kupuj',
#   '2,37 zł',
#   '4,30 zł',
#   '81,43%',
#   '2,10 zł',
#   'East Value Research',
#   '08.02.2024',
#   ''],
#  ['FERRO (FRO)*',
#   'Kupuj',
#   '37,70 zł',
#   '36,60 zł',
#   '-2,92%',
#   '32,30 zł',
#   'DM BOŚ',
#   '07.02.2024',
#   ''],
#  ['RELPOL (RLP)*',
#   'Trzymaj',
#   '5,92 zł',
#   '7,42 zł',
#   '25,34%',
#   '7,08 zł',
#   'DM BDM',
#   '05.02.2024',
#   ''],
#  ['SECOGROUP (SWG)*',
#   'Kupuj',
#   '33,60 zł',
#   '36,20 zł',
#   '7,74%',
#   '31,20 zł',
#   'Erste',
#   '02.02.2024',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 680,00 zł',
#   '20 000,00 zł',
#   '19,90%',
#   '15 570,00 zł',
#   'BM mBank',
#   '01.02.2024',
#   ''],
#  ['11BIT (11B)',
#   'Kupuj',
#   '633,00 zł',
#   '808,00 zł',
#   '27,65%',
#   '572,00 zł',
#   'DM BDM',
#   '30.01.2024',
#   ''],
#  ['MOLECURE (MOC)',
#   'Kupuj',
#   '14,00 zł',
#   '34,00 zł',
#   '142,86%',
#   '18,70 zł',
#   'BM mBank',
#   '23.01.2024',
#   ''],
#  ['KRUK (KRU)',
#   'Kupuj',
#   '437,00 zł',
#   '532,36 zł',
#   '21,82%',
#   '457,20 zł',
#   'BM mBank',
#   '18.01.2024',
#   ''],
#  ['FORTE (FTE)',
#   'Akumuluj',
#   '21,60 zł',
#   '25,20 zł',
#   '16,67%',
#   '23,10 zł',
#   'Noble Securities',
#   '17.01.2024',
#   ''],
#  ['AGORA (AGO)*',
#   'Kupuj',
#   '10,90 zł',
#   '14,50 zł',
#   '33,03%',
#   '10,45 zł',
#   'DM BDM',
#   '09.01.2024',
#   ''],
#  ['WIRTUALNA (WPL)',
#   'Redukuj',
#   '111,00 zł',
#   '102,80 zł',
#   '-7,39%',
#   '118,00 zł',
#   'DM BDM',
#   '09.01.2024',
#   ''],
#  ['VIGOPHOTN (VGO)',
#   'Kupuj',
#   '510,00 zł',
#   '590,00 zł',
#   '15,69%',
#   '510,00 zł',
#   'East Value Research',
#   '08.01.2024',
#   ''],
#  ['PEKABEX (PBX)',
#   'Kupuj',
#   '26,50 zł',
#   '27,30 zł',
#   '3,02%',
#   '24,30 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['TORPOL (TOR)',
#   'Kupuj',
#   '34,75 zł',
#   '27,90 zł',
#   '-19,71%',
#   '24,90 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['MIRBUD (MRB)',
#   'Akumuluj',
#   '12,74 zł',
#   '9,09 zł',
#   '-28,65%',
#   '8,30 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['ERBUD (ERB)',
#   'Trzymaj',
#   '40,60 zł',
#   '41,10 zł',
#   '1,23%',
#   '41,30 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['INSTALKRK (INK)',
#   'Kupuj',
#   '46,30 zł',
#   '50,00 zł',
#   '7,99%',
#   '42,80 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['MOSTALZAB (MSZ)',
#   'Kupuj',
#   '4,23 zł',
#   '4,85 zł',
#   '14,66%',
#   '4,00 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['BUDIMEX (BDX)',
#   'Redukuj',
#   '672,50 zł',
#   '530,80 zł',
#   '-21,07%',
#   '636,00 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['ZUE (ZUE)*',
#   'Akumuluj',
#   '10,75 zł',
#   '8,43 zł',
#   '-21,58%',
#   '7,86 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['ELEKTROTI (ELT)*',
#   'Akumuluj',
#   '30,60 zł',
#   '19,10 zł',
#   '-37,58%',
#   '17,48 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['VOXEL (VOX)',
#   'Kupuj',
#   '90,00 zł',
#   '90,30 zł',
#   '0,33%',
#   '78,60 zł',
#   'DM BDM',
#   '02.01.2024',
#   ''],
#  ['OPONEO.PL (OPN)',
#   'Kupuj',
#   '78,40 zł',
#   '63,80 zł',
#   '-18,62%',
#   '46,50 zł',
#   'East Value Research',
#   '27.12.2023',
#   ''],
#  ['HUUUGE (HUG)',
#   'Kupuj',
#   '22,85 zł',
#   '36,20 zł',
#   '58,42%',
#   '26,90 zł',
#   'DM BDM',
#   '22.12.2023',
#   ''],
#  ['GRODNO (GRN)*',
#   'Trzymaj',
#   '10,88 zł',
#   '11,80 zł',
#   '8,46%',
#   '10,94 zł',
#   'DM BOŚ',
#   '19.12.2023',
#   ''],
#  ['AMICA (AMC)',
#   'Kupuj',
#   '73,00 zł',
#   '109,20 zł',
#   '49,59%',
#   '82,00 zł',
#   'Noble Securities',
#   '15.12.2023',
#   ''],
#  ['SYNEKTIK (SNT)',
#   'Kupuj',
#   '141,40 zł',
#   '109,70 zł',
#   '-22,42%',
#   '89,20 zł',
#   'East Value Research',
#   '14.12.2023',
#   ''],
#  ['MARVIPOL (MVP)*',
#   'Kupuj',
#   '6,70 zł',
#   '10,07 zł',
#   '50,30%',
#   '7,20 zł',
#   'Ipopema Securities',
#   '12.12.2023',
#   ''],
#  ['KINOPOL (KPL)*',
#   'Wycena',
#   '17,25 zł',
#   '18,40 zł',
#   '6,67%',
#   '14,65 zł',
#   'DM BDM',
#   '11.12.2023',
#   ''],
#  ['BRAND24 (B24)*',
#   'Wycena',
#   '46,20 zł',
#   '48,80 zł',
#   '5,63%',
#   '36,30 zł',
#   'DM BOŚ',
#   '11.12.2023',
#   ''],
#  ['VOXEL (VOX)*',
#   'Kupuj',
#   '90,00 zł',
#   '85,30 zł',
#   '-5,22%',
#   '74,20 zł',
#   'DM BOŚ',
#   '11.12.2023',
#   ''],
#  ['CLOUD (CLD)*',
#   'Trzymaj',
#   '73,00 zł',
#   '71,00 zł',
#   '-2,74%',
#   '68,00 zł',
#   'DM BOŚ',
#   '11.12.2023',
#   ''],
#  ['VOTUM (VOT)*',
#   'Kupuj',
#   '35,70 zł',
#   '81,30 zł',
#   '127,73%',
#   '43,70 zł',
#   'DM BOŚ',
#   '11.12.2023',
#   ''],
#  ['DATAWALK (DAT)*',
#   'Trzymaj',
#   '64,60 zł',
#   '53,00 zł',
#   '-17,96%',
#   '32,50 zł',
#   'DM BOŚ',
#   '11.12.2023',
#   ''],
#  ['FERRO (FRO)*',
#   'Kupuj',
#   '37,70 zł',
#   '34,70 zł',
#   '-7,96%',
#   '31,60 zł',
#   'DM BOŚ',
#   '11.12.2023',
#   ''],
#  ['KINOPOL (KPL)*',
#   'Kupuj',
#   '17,25 zł',
#   '18,40 zł',
#   '6,67%',
#   '14,00 zł',
#   'DM BDM',
#   '11.12.2023',
#   ''],
#  ['MCI (MCI)*',
#   'Wycena',
#   '25,50 zł',
#   '40,30 zł',
#   '58,04%',
#   '23,70 zł',
#   'Noble Securities',
#   '08.12.2023',
#   ''],
#  ['KOGENERA (KGN)',
#   'Wycena',
#   '46,80 zł',
#   '137,00 zł',
#   '192,74%',
#   '42,00 zł',
#   'East Value Research',
#   '08.12.2023',
#   ''],
#  ['BOWIM (BOW)*',
#   'Wycena',
#   '6,75 zł',
#   '7,20 zł',
#   '6,67%',
#   '7,20 zł',
#   'DM BOŚ',
#   '08.12.2023',
#   ''],
#  ['AILLERON (ALL)',
#   'Wycena',
#   '17,62 zł',
#   '22,70 zł',
#   '28,83%',
#   '19,20 zł',
#   'Noble Securities',
#   '07.12.2023',
#   ''],
#  ['CLNPHARMA (CLN)',
#   'Kupuj',
#   '15,42 zł',
#   '29,10 zł',
#   '88,72%',
#   '15,66 zł',
#   'Noble Securities',
#   '06.12.2023',
#   ''],
#  ['SONEL (SON)*',
#   'Wycena',
#   '17,85 zł',
#   '12,36 zł',
#   '-30,76%',
#   '11,70 zł',
#   'Noble Securities',
#   '05.12.2023',
#   ''],
#  ['CAPTORTX (CTX)',
#   'Kupuj',
#   '79,00 zł',
#   '137,10 zł',
#   '73,54%',
#   '86,60 zł',
#   'Noble Securities',
#   '04.12.2023',
#   ''],
#  ['PEKAO (PEO)',
#   'Kupuj',
#   '155,75 zł',
#   '201,80 zł',
#   '29,57%',
#   '147,80 zł',
#   'DM BOŚ',
#   '04.12.2023',
#   ''],
#  ['PKOBP (PKO)',
#   'Kupuj',
#   '57,30 zł',
#   '64,40 zł',
#   '12,39%',
#   '49,55 zł',
#   'DM BOŚ',
#   '04.12.2023',
#   ''],
#  ['MILLENNIUM (MIL)',
#   'Kupuj',
#   '8,02 zł',
#   '11,30 zł',
#   '40,90%',
#   '8,11 zł',
#   'DM BOŚ',
#   '04.12.2023',
#   ''],
#  ['WARIMPEX (WXF)',
#   'Wycena',
#   '3,78 zł',
#   '11,68 zł',
#   '208,99%',
#   '3,48 zł',
#   'East Value Research',
#   '04.12.2023',
#   ''],
#  ['ALLEGRO (ALE)',
#   'Kupuj',
#   '36,77 zł',
#   '35,30 zł',
#   '-3,98%',
#   '28,94 zł',
#   'BM mBank',
#   '01.12.2023',
#   ''],
#  ['ARTIFEX (ART)*',
#   'Kupuj',
#   '22,10 zł',
#   '24,80 zł',
#   '12,22%',
#   '16,95 zł',
#   'DM BDM',
#   '01.12.2023',
#   ''],
#  ['IFIRMA (IFI)*',
#   'Neutralna',
#   '23,20 zł',
#   '30,90 zł',
#   '33,19%',
#   '29,80 zł',
#   'Millennium DM',
#   '30.11.2023',
#   ''],
#  ['MOSTALZAB (MSZ)*',
#   'Kupuj',
#   '4,23 zł',
#   '5,80 zł',
#   '37,12%',
#   '3,87 zł',
#   'Millennium DM',
#   '30.11.2023',
#   ''],
#  ['TSGAMES (TEN)',
#   'Kupuj',
#   '82,00 zł',
#   '138,00 zł',
#   '68,29%',
#   '90,35 zł',
#   'DM BDM',
#   '30.11.2023',
#   ''],
#  ['FERRO (FRO)*',
#   'Kupuj',
#   '37,70 zł',
#   '33,30 zł',
#   '-11,67%',
#   '26,60 zł',
#   'DM BOŚ',
#   '29.11.2023',
#   ''],
#  ['XTB (XTB)',
#   'Kupuj',
#   '66,56 zł',
#   '67,70 zł',
#   '1,71%',
#   '34,10 zł',
#   'Noble Securities',
#   '28.11.2023',
#   ''],
#  ['MOBRUK (MBR)',
#   'Kupuj',
#   '310,50 zł',
#   '390,30 zł',
#   '25,70%',
#   '280,00 zł',
#   'Noble Securities',
#   '28.11.2023',
#   ''],
#  ['SELVITA (SLV)',
#   'Akumuluj',
#   '63,70 zł',
#   '72,60 zł',
#   '13,97%',
#   '60,00 zł',
#   'Noble Securities',
#   '28.11.2023',
#   ''],
#  ['DECORA (DCR)',
#   'Kupuj',
#   '66,80 zł',
#   '60,40 zł',
#   '-9,58%',
#   '54,20 zł',
#   'DM BOŚ',
#   '28.11.2023',
#   ''],
#  ['ALIOR (ALR)',
#   'Kupuj',
#   '91,20 zł',
#   '93,30 zł',
#   '2,30%',
#   '74,36 zł',
#   'DM BOŚ',
#   '27.11.2023',
#   ''],
#  ['SHOPER (SHO)',
#   'Kupuj',
#   '41,70 zł',
#   '36,50 zł',
#   '-12,47%',
#   '33,50 zł',
#   'BM mBank',
#   '23.11.2023',
#   ''],
#  ['PEPCO (PCO)',
#   'Trzymaj',
#   '23,10 zł',
#   '19,00 zł',
#   '-17,75%',
#   '19,37 zł',
#   'Noble Securities',
#   '20.11.2023',
#   ''],
#  ['GRUPRACUJ (GPP)',
#   'Trzymaj',
#   '59,50 zł',
#   '63,40 zł',
#   '6,55%',
#   '61,00 zł',
#   'BM Banku Pekao',
#   '20.11.2023',
#   ''],
#  ['PKOBP (PKO)',
#   'Kupuj',
#   '57,30 zł',
#   '55,21 zł',
#   '-3,65%',
#   '47,68 zł',
#   'BM mBank',
#   '17.11.2023',
#   ''],
#  ['GRUPAAZOTY (ATT)',
#   'Sprzedaj',
#   '21,52 zł',
#   '17,26 zł',
#   '-19,80%',
#   '21,30 zł',
#   'BM Banku Pekao',
#   '17.11.2023',
#   ''],
#  ['PCCROKITA (PCR)',
#   'Sprzedaj',
#   '90,00 zł',
#   '79,04 zł',
#   '-12,18%',
#   '91,00 zł',
#   'BM Banku Pekao',
#   '17.11.2023',
#   ''],
#  ['SCPFL (SCP)*',
#   'Kupuj',
#   '169,80 zł',
#   '230,20 zł',
#   '35,57%',
#   '165,00 zł',
#   'Ipopema Securities',
#   '16.11.2023',
#   ''],
#  ['MEDICALG (MDG)*',
#   'Kupuj',
#   '26,02 zł',
#   '41,20 zł',
#   '58,34%',
#   '26,25 zł',
#   'Ipopema Securities',
#   '16.11.2023',
#   ''],
#  ['PEPCO (PCO)',
#   'Kupuj',
#   '23,10 zł',
#   '32,70 zł',
#   '41,56%',
#   '19,00 zł',
#   'BM mBank',
#   '15.11.2023',
#   ''],
#  ['RYVU (RVU)',
#   'Kupuj',
#   '51,50 zł',
#   '77,70 zł',
#   '50,87%',
#   '56,90 zł',
#   'Noble Securities',
#   '15.11.2023',
#   ''],
#  ['SANOK (SNK)',
#   'Trzymaj',
#   '20,20 zł',
#   '24,80 zł',
#   '22,77%',
#   '23,10 zł',
#   'DM BOŚ',
#   '10.11.2023',
#   ''],
#  ['RYVU (RVU)',
#   'Trzymaj',
#   '51,50 zł',
#   '65,00 zł',
#   '26,21%',
#   '56,70 zł',
#   'BM mBank',
#   '07.11.2023',
#   ''],
#  ['ORANGEPL (OPL)',
#   'Kupuj',
#   '8,00 zł',
#   '9,60 zł',
#   '20,03%',
#   '8,02 zł',
#   'BM mBank',
#   '07.11.2023',
#   ''],
#  ['SELVITA (SLV)',
#   'Trzymaj',
#   '63,70 zł',
#   '74,20 zł',
#   '16,48%',
#   '59,50 zł',
#   'DM BOŚ',
#   '07.11.2023',
#   ''],
#  ['BOOMBIT (BBT)',
#   'Kupuj',
#   '11,20 zł',
#   '18,90 zł',
#   '68,75%',
#   '10,85 zł',
#   'DM BDM',
#   '06.11.2023',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 680,00 zł',
#   '18 105,00 zł',
#   '8,54%',
#   '13 900,00 zł',
#   'DM BOŚ',
#   '06.11.2023',
#   ''],
#  ['DATAWALK (DAT)*',
#   'Trzymaj',
#   '64,60 zł',
#   '53,00 zł',
#   '-17,96%',
#   '50,50 zł',
#   'DM BOŚ',
#   '03.11.2023',
#   ''],
#  ['VOXEL (VOX)*',
#   'Kupuj',
#   '90,00 zł',
#   '75,80 zł',
#   '-15,78%',
#   '59,60 zł',
#   'DM BOŚ',
#   '02.11.2023',
#   ''],
#  ['SANPL (SPL)',
#   'Kupuj',
#   '492,60 zł',
#   '486,63 zł',
#   '-1,21%',
#   '456,40 zł',
#   'BM mBank',
#   '02.11.2023',
#   ''],
#  ['ASSECOSEE (ASE)',
#   'Kupuj',
#   '49,90 zł',
#   '50,00 zł',
#   '0,20%',
#   '46,00 zł',
#   'DM BOŚ',
#   '02.11.2023',
#   ''],
#  ['ACTION (ACT)*',
#   'Kupuj',
#   '20,00 zł',
#   '21,60 zł',
#   '8,00%',
#   '18,40 zł',
#   'DM BOŚ',
#   '02.11.2023',
#   ''],
#  ['UNIMOT (UNT)',
#   'Trzymaj',
#   '130,80 zł',
#   '105,00 zł',
#   '-19,72%',
#   '100,40 zł',
#   'DM BOŚ',
#   '31.10.2023',
#   ''],
#  ['PEKABEX (PBX)',
#   'Kupuj',
#   '26,50 zł',
#   '24,00 zł',
#   '-9,43%',
#   '21,30 zł',
#   'Trigon DM',
#   '30.10.2023',
#   ''],
#  ['VOXEL (VOX)*',
#   'Kupuj',
#   '90,00 zł',
#   '73,90 zł',
#   '-17,89%',
#   '53,00 zł',
#   'DM BOŚ',
#   '30.10.2023',
#   ''],
#  ['FERRO (FRO)*',
#   'Neutralna',
#   '37,70 zł',
#   '30,10 zł',
#   '-20,16%',
#   '27,20 zł',
#   'DM BOŚ',
#   '25.10.2023',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 680,00 zł',
#   '16 795,00 zł',
#   '0,69%',
#   '12 670,00 zł',
#   'Noble Securities',
#   '25.10.2023',
#   ''],
#  ['DADELO (DAD)*',
#   'Kupuj',
#   '20,10 zł',
#   '18,50 zł',
#   '-7,96%',
#   '16,30 zł',
#   'Trigon DM',
#   '24.10.2023',
#   ''],
#  ['AILLERON (ALL)',
#   'Kupuj',
#   '17,62 zł',
#   '28,00 zł',
#   '58,91%',
#   '19,00 zł',
#   'Trigon DM',
#   '23.10.2023',
#   ''],
#  ['SELENAFM (SEL)',
#   'Kupuj',
#   '34,50 zł',
#   '42,50 zł',
#   '23,19%',
#   '29,90 zł',
#   'Trigon DM',
#   '23.10.2023',
#   ''],
#  ['MFO (MFO)*',
#   'Kupuj',
#   '31,30 zł',
#   '42,60 zł',
#   '36,10%',
#   '29,30 zł',
#   'Trigon DM',
#   '23.10.2023',
#   ''],
#  ['KOGENERA (KGN)',
#   'Wycena',
#   '46,80 zł',
#   '150,30 zł',
#   '221,15%',
#   '39,70 zł',
#   'East Value Research',
#   '23.10.2023',
#   ''],
#  ['MANGATA (MGT)',
#   'Kupuj',
#   '102,00 zł',
#   '110,40 zł',
#   '8,24%',
#   '94,00 zł',
#   'DM BOŚ',
#   '20.10.2023',
#   ''],
#  ['ASSECOPOL (ACP)',
#   'Trzymaj',
#   '81,45 zł',
#   '84,30 zł',
#   '3,50%',
#   '76,05 zł',
#   'DM BOŚ',
#   '20.10.2023',
#   ''],
#  ['PCCROKITA (PCR)',
#   'Trzymaj',
#   '90,00 zł',
#   '100,00 zł',
#   '11,11%',
#   '98,80 zł',
#   'DM BOŚ',
#   '18.10.2023',
#   ''],
#  ['KRUK (KRU)',
#   'Kupuj',
#   '437,00 zł',
#   '493,25 zł',
#   '12,87%',
#   '461,40 zł',
#   'BM mBank',
#   '17.10.2023',
#   ''],
#  ['KETY (KTY)',
#   'Trzymaj',
#   '842,00 zł',
#   '696,20 zł',
#   '-17,32%',
#   '638,00 zł',
#   'BM mBank',
#   '13.10.2023',
#   ''],
#  ['SUNEX (SNX)',
#   'Trzymaj',
#   '10,18 zł',
#   '12,00 zł',
#   '17,88%',
#   '13,06 zł',
#   'Ipopema Securities',
#   '13.10.2023',
#   ''],
#  ['JSW (JSW)',
#   'Kupuj',
#   '29,10 zł',
#   '65,00 zł',
#   '123,37%',
#   '43,70 zł',
#   'DM BOŚ',
#   '13.10.2023',
#   ''],
#  ['ATAL (1AT)',
#   'Kupuj',
#   '58,00 zł',
#   '72,82 zł',
#   '25,55%',
#   '62,20 zł',
#   'BM mBank',
#   '10.10.2023',
#   ''],
#  ['ELEKTROTI (ELT)*',
#   'Kupuj',
#   '30,60 zł',
#   '17,10 zł',
#   '-44,12%',
#   '14,42 zł',
#   'DM BDM',
#   '10.10.2023',
#   ''],
#  ['AUTOPARTN (APR)',
#   'Kupuj',
#   '24,65 zł',
#   '33,90 zł',
#   '37,53%',
#   '23,00 zł',
#   'Noble Securities',
#   '09.10.2023',
#   ''],
#  ['INTERCARS (CAR)',
#   'Kupuj',
#   '540,00 zł',
#   '708,00 zł',
#   '31,11%',
#   '560,00 zł',
#   'Noble Securities',
#   '09.10.2023',
#   ''],
#  ['WITTCHEN (WTN)',
#   'Kupuj',
#   '31,90 zł',
#   '30,40 zł',
#   '-4,70%',
#   '23,80 zł',
#   'DM Banku BPS',
#   '06.10.2023',
#   ''],
#  ['4MASS (4MS)',
#   'Kupuj',
#   '5,90 zł',
#   '13,20 zł',
#   '123,73%',
#   '5,99 zł',
#   'East Value Research',
#   '05.10.2023',
#   ''],
#  ['DEVELIA (DVL)',
#   'Kupuj',
#   '5,35 zł',
#   '5,62 zł',
#   '5,05%',
#   '4,88 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['DOMDEV (DOM)',
#   'Trzymaj',
#   '180,80 zł',
#   '153,52 zł',
#   '-15,09%',
#   '153,80 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['ALIOR (ALR)',
#   'Kupuj',
#   '91,20 zł',
#   '65,00 zł',
#   '-28,73%',
#   '52,50 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['PKOBP (PKO)',
#   'Kupuj',
#   '57,30 zł',
#   '44,90 zł',
#   '-21,64%',
#   '34,57 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['INGBSK (ING)',
#   'Kupuj',
#   '277,50 zł',
#   '209,00 zł',
#   '-24,68%',
#   '179,40 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['BOS (BOS)',
#   'Kupuj',
#   '12,90 zł',
#   '11,36 zł',
#   '-11,94%',
#   '8,44 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['MILLENNIUM (MIL)',
#   'Kupuj',
#   '8,02 zł',
#   '7,15 zł',
#   '-10,85%',
#   '5,85 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['BNPPPL (BNP)',
#   'Kupuj',
#   '97,00 zł',
#   '71,58 zł',
#   '-26,21%',
#   '56,60 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['SANPL (SPL)',
#   'Kupuj',
#   '492,60 zł',
#   '413,63 zł',
#   '-16,03%',
#   '360,60 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['PEKAO (PEO)',
#   'Kupuj',
#   '155,75 zł',
#   '141,97 zł',
#   '-8,85%',
#   '101,00 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['AMBRA (AMB)*',
#   'Kupuj',
#   '27,70 zł',
#   '35,90 zł',
#   '29,60%',
#   '29,30 zł',
#   'Millennium DM',
#   '04.10.2023',
#   ''],
#  ['HANDLOWY (BHW)',
#   'Kupuj',
#   '105,00 zł',
#   '99,00 zł',
#   '-5,71%',
#   '79,70 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['BRAND24 (B24)*',
#   'Wycena',
#   '46,20 zł',
#   '48,80 zł',
#   '5,63%',
#   '36,00 zł',
#   'DM BOŚ',
#   '04.10.2023',
#   ''],
#  ['VOTUM (VOT)*',
#   'Kupuj',
#   '35,70 zł',
#   '79,50 zł',
#   '122,69%',
#   '43,10 zł',
#   'DM BOŚ',
#   '04.10.2023',
#   ''],
#  ['BENEFIT (BFT)',
#   'Kupuj',
#   '2 790,00 zł',
#   '2 100,00 zł',
#   '-24,73%',
#   '1 730,00 zł',
#   'DM BOŚ',
#   '03.10.2023',
#   ''],
#  ['MABION (MAB)',
#   'Wycena',
#   '17,26 zł',
#   '23,60 zł',
#   '36,73%',
#   '16,99 zł',
#   'Noble Securities',
#   '02.10.2023',
#   ''],
#  ['MLSYSTEM (MLS)*',
#   'Kupuj',
#   '42,30 zł',
#   '87,20 zł',
#   '106,15%',
#   '65,30 zł',
#   'Ipopema Securities',
#   '02.10.2023',
#   ''],
#  ['RELPOL (RLP)*',
#   'Trzymaj',
#   '5,92 zł',
#   '8,62 zł',
#   '45,61%',
#   '8,46 zł',
#   'DM BDM',
#   '26.09.2023',
#   ''],
#  ['RAEN (RAE)',
#   'Wycena',
#   '0,61 zł',
#   '1,90 zł',
#   '209,95%',
#   '0,51 zł',
#   'East Value Research',
#   '26.09.2023',
#   ''],
#  ['EUROCASH (EUR)',
#   'Trzymaj',
#   '12,62 zł',
#   '15,00 zł',
#   '18,86%',
#   '15,20 zł',
#   'Noble Securities',
#   '22.09.2023',
#   ''],
#  ['DINOPL (DNP)',
#   'Akumuluj',
#   '398,10 zł',
#   '431,80 zł',
#   '8,47%',
#   '373,10 zł',
#   'Noble Securities',
#   '22.09.2023',
#   ''],
#  ['MIRACULUM (MIR)',
#   'Trzymaj',
#   '1,15 zł',
#   '1,25 zł',
#   '8,70%',
#   '1,33 zł',
#   'Ipopema Securities',
#   '22.09.2023',
#   ''],
#  ['TORPOL (TOR)',
#   'Trzymaj',
#   '34,75 zł',
#   '19,30 zł',
#   '-44,46%',
#   '18,66 zł',
#   'DM BDM',
#   '20.09.2023',
#   ''],
#  ['BIOTON (BIO)*',
#   'Wycena',
#   '3,50 zł',
#   '5,41 zł',
#   '54,57%',
#   '3,83 zł',
#   'Noble Securities',
#   '19.09.2023',
#   ''],
#  ['UNIBEP (UNI)',
#   'Wycena',
#   '9,32 zł',
#   '12,50 zł',
#   '34,12%',
#   '10,40 zł',
#   'Noble Securities',
#   '15.09.2023',
#   ''],
#  ['BIOMAXIMA (BMX)',
#   'Kupuj',
#   '16,15 zł',
#   '26,40 zł',
#   '63,47%',
#   '19,20 zł',
#   'DM BDM',
#   '15.09.2023',
#   ''],
#  ['SYGNITY (SGN)*',
#   'Sprzedaj',
#   '64,00 zł',
#   '21,60 zł',
#   '-66,25%',
#   '32,80 zł',
#   'BM mBank',
#   '15.09.2023',
#   ''],
#  ['SELENAFM (SEL)',
#   'Kupuj',
#   '34,50 zł',
#   '40,40 zł',
#   '17,10%',
#   '25,40 zł',
#   'Trigon DM',
#   '14.09.2023',
#   ''],
#  ['ATMGRUPA (ATG)',
#   'Kupuj',
#   '4,15 zł',
#   '4,51 zł',
#   '8,67%',
#   '3,29 zł',
#   'DM BDM',
#   '14.09.2023',
#   ''],
#  ['AGORA (AGO)',
#   'Kupuj',
#   '10,90 zł',
#   '10,46 zł',
#   '-4,04%',
#   '7,84 zł',
#   'DM BDM',
#   '13.09.2023',
#   ''],
#  ['ZUE (ZUE)',
#   'Kupuj',
#   '10,75 zł',
#   '7,76 zł',
#   '-27,81%',
#   '5,62 zł',
#   'DM BDM',
#   '12.09.2023',
#   ''],
#  ['CLOUD (CLD)',
#   'Wycena',
#   '73,00 zł',
#   '88,00 zł',
#   '20,55%',
#   '94,00 zł',
#   'DM BOŚ',
#   '11.09.2023',
#   ''],
#  ['SCPFL (SCP)*',
#   'Kupuj',
#   '169,80 zł',
#   '235,80 zł',
#   '38,87%',
#   '165,00 zł',
#   'Ipopema Securities',
#   '11.09.2023',
#   ''],
#  ['CYBERFLKS (CBF)',
#   'Kupuj',
#   '120,00 zł',
#   '95,00 zł',
#   '-20,83%',
#   '81,00 zł',
#   'BM mBank',
#   '11.09.2023',
#   ''],
#  ['VERCOM (VRC)',
#   'Trzymaj',
#   '122,00 zł',
#   '67,40 zł',
#   '-44,75%',
#   '69,40 zł',
#   'BM mBank',
#   '11.09.2023',
#   ''],
#  ['PGE (PGE)',
#   'Kupuj',
#   '6,70 zł',
#   '11,00 zł',
#   '64,18%',
#   '7,57 zł',
#   'DM BOŚ',
#   '11.09.2023',
#   ''],
#  ['BOWIM (BOW)',
#   'Wycena',
#   '6,75 zł',
#   '6,90 zł',
#   '2,22%',
#   '7,05 zł',
#   'DM BOŚ',
#   '11.09.2023',
#   ''],
#  ['ZEPAK (ZEP)',
#   'Trzymaj',
#   '19,00 zł',
#   '20,60 zł',
#   '8,42%',
#   '20,20 zł',
#   'BM Banku Pekao',
#   '11.09.2023',
#   ''],
#  ['ATENDE (ATD)',
#   'Kupuj',
#   '2,97 zł',
#   '4,80 zł',
#   '61,62%',
#   '2,90 zł',
#   'BM Banku Pekao',
#   '11.09.2023',
#   ''],
#  ['SECOGROUP (SWG)*',
#   'Kupuj',
#   '33,60 zł',
#   '33,33 zł',
#   '-0,80%',
#   '26,00 zł',
#   'Erste',
#   '08.09.2023',
#   ''],
#  ['IFIRMA (IFI)',
#   'Akumuluj',
#   '23,20 zł',
#   '36,60 zł',
#   '57,76%',
#   '33,30 zł',
#   'Millennium DM',
#   '08.09.2023',
#   ''],
#  ['SKARBIEC (SKH)',
#   'Kupuj',
#   '22,90 zł',
#   '32,00 zł',
#   '39,74%',
#   '20,40 zł',
#   'BM Banku Pekao',
#   '08.09.2023',
#   ''],
#  ['QUERCUS (QRS)',
#   'Kupuj',
#   '6,02 zł',
#   '5,30 zł',
#   '-11,96%',
#   '4,03 zł',
#   'BM Banku Pekao',
#   '08.09.2023',
#   ''],
#  ['STALPROFI (STF)',
#   'Sprzedaj',
#   '9,16 zł',
#   '8,00 zł',
#   '-12,66%',
#   '8,64 zł',
#   'BM Banku Pekao',
#   '08.09.2023',
#   ''],
#  ['IMS (IMS)',
#   'Kupuj',
#   '4,54 zł',
#   '3,80 zł',
#   '-16,30%',
#   '2,80 zł',
#   'Millennium DM',
#   '08.09.2023',
#   ''],
#  ['MABION (MAB)',
#   'Wycena',
#   '17,26 zł',
#   '22,90 zł',
#   '32,68%',
#   '17,96 zł',
#   'Noble Securities',
#   '08.09.2023',
#   ''],
#  ['MLPGROUP (MLG)*',
#   'Kupuj',
#   '82,00 zł',
#   '115,00 zł',
#   '40,24%',
#   '78,20 zł',
#   'BM PKO BP',
#   '08.09.2023',
#   ''],
#  ['MARVIPOL (MVP)',
#   'Kupuj',
#   '6,70 zł',
#   '10,49 zł',
#   '56,57%',
#   '8,00 zł',
#   'Ipopema Securities',
#   '07.09.2023',
#   ''],
#  ['MERCOR (MCR)',
#   'Kupuj',
#   '24,00 zł',
#   '37,00 zł',
#   '54,17%',
#   '25,20 zł',
#   'BM Banku Pekao',
#   '06.09.2023',
#   ''],
#  ['WARIMPEX (WXF)',
#   'Wycena',
#   '3,78 zł',
#   '8,99 zł',
#   '137,83%',
#   '4,90 zł',
#   'East Value Research',
#   '05.09.2023',
#   ''],
#  ['SYNEKTIK (SNT)',
#   'Kupuj',
#   '141,40 zł',
#   '87,00 zł',
#   '-38,47%',
#   '72,60 zł',
#   'BM mBank',
#   '05.09.2023',
#   ''],
#  ['NEWAG (NWG)',
#   'Przeważaj',
#   '26,60 zł',
#   '25,00 zł',
#   '-6,02%',
#   '18,20 zł',
#   'Santander BM',
#   '05.09.2023',
#   ''],
#  ['WARIMPEX (WXF)',
#   '',
#   '3,78 zł',
#   '2,11 zł',
#   '-44,18%',
#   '4,78 zł',
#   'East Value Research',
#   '05.09.2023',
#   ''],
#  ['PEPCO (PCO)',
#   'Kupuj',
#   '23,10 zł',
#   '42,10 zł',
#   '82,25%',
#   '32,70 zł',
#   'Noble Securities',
#   '04.09.2023',
#   ''],
#  ['VINDEXUS (VIN)',
#   'Kupuj',
#   '8,82 zł',
#   '13,90 zł',
#   '57,60%',
#   '8,10 zł',
#   'East Value Research',
#   '04.09.2023',
#   ''],
#  ['XTPL (XTP)',
#   'Kupuj',
#   '128,00 zł',
#   '216,00 zł',
#   '68,75%',
#   '165,00 zł',
#   'Erste',
#   '31.08.2023',
#   ''],
#  ['SYNEKTIK (SNT)',
#   'Kupuj',
#   '141,40 zł',
#   '95,50 zł',
#   '-32,46%',
#   '67,60 zł',
#   'East Value Research',
#   '31.08.2023',
#   ''],
#  ['ARTIFEX (ART)',
#   'Kupuj',
#   '22,10 zł',
#   '22,80 zł',
#   '3,17%',
#   '17,60 zł',
#   'DM BDM',
#   '30.08.2023',
#   ''],
#  ['AILLERON (ALL)',
#   'Kupuj',
#   '17,62 zł',
#   '26,00 zł',
#   '47,56%',
#   '18,40 zł',
#   'Trigon DM',
#   '30.08.2023',
#   ''],
#  ['ENTER (ENT)*',
#   'Kupuj',
#   '64,70 zł',
#   '59,80 zł',
#   '-7,57%',
#   '43,50 zł',
#   'DM BDM',
#   '29.08.2023',
#   ''],
#  ['SYNEKTIK (SNT)',
#   'Kupuj',
#   '141,40 zł',
#   '87,00 zł',
#   '-38,47%',
#   '68,60 zł',
#   'BM mBank',
#   '28.08.2023',
#   ''],
#  ['WIRTUALNA (WPL)',
#   'Akumuluj',
#   '111,00 zł',
#   '129,10 zł',
#   '16,31%',
#   '114,20 zł',
#   'DM BDM',
#   '28.08.2023',
#   ''],
#  ['ASBIS (ASB)',
#   'Wycena',
#   '24,94 zł',
#   '67,00 zł',
#   '168,64%',
#   '28,74 zł',
#   'Argus Research',
#   '25.08.2023',
#   ''],
#  ['OPONEO.PL (OPN)*',
#   'Kupuj',
#   '78,40 zł',
#   '51,00 zł',
#   '-34,95%',
#   '43,00 zł',
#   'BM PKO BP',
#   '23.08.2023',
#   ''],
#  ['ORANGEPL (OPL)',
#   'Kupuj',
#   '8,00 zł',
#   '8,87 zł',
#   '10,90%',
#   '6,83 zł',
#   'DM BDM',
#   '21.08.2023',
#   ''],
#  ['NEUCA (NEU)',
#   'Kupuj',
#   '892,00 zł',
#   '855,00 zł',
#   '-4,15%',
#   '750,00 zł',
#   'DM BOŚ',
#   '17.08.2023',
#   ''],
#  ['INTERCARS (CAR)',
#   'Trzymaj',
#   '540,00 zł',
#   '595,00 zł',
#   '10,19%',
#   '589,00 zł',
#   'DM BOŚ',
#   '16.08.2023',
#   ''],
#  ['BOGDANKA (LWB)',
#   'Sprzedaj',
#   '29,42 zł',
#   '33,00 zł',
#   '12,17%',
#   '35,52 zł',
#   'DM BOŚ',
#   '16.08.2023',
#   ''],
#  ['SECOGROUP (SWG)',
#   'Kupuj',
#   '33,60 zł',
#   '33,32 zł',
#   '-0,83%',
#   '27,80 zł',
#   'Erste',
#   '16.08.2023',
#   ''],
#  ['ABPL (ABE)',
#   'Kupuj',
#   '101,00 zł',
#   '82,60 zł',
#   '-18,22%',
#   '59,60 zł',
#   'DM BOŚ',
#   '11.08.2023',
#   ''],
#  ['BOGDANKA (LWB)',
#   'Akumuluj',
#   '29,42 zł',
#   '42,28 zł',
#   '43,71%',
#   '36,20 zł',
#   'Noble Securities',
#   '04.08.2023',
#   ''],
#  ['SNIEZKA (SKA)',
#   'Akumuluj',
#   '85,00 zł',
#   '79,90 zł',
#   '-6,00%',
#   '72,80 zł',
#   'DM BDM',
#   '04.08.2023',
#   ''],
#  ['VOXEL (VOX)*',
#   'Kupuj',
#   '90,00 zł',
#   '66,30 zł',
#   '-26,33%',
#   '53,60 zł',
#   'DM BOŚ',
#   '03.08.2023',
#   ''],
#  ['FERRO (FRO)*',
#   'Trzymaj',
#   '37,70 zł',
#   '30,10 zł',
#   '-20,16%',
#   '30,00 zł',
#   'DM BOŚ',
#   '01.08.2023',
#   ''],
#  ['ARCHICOM (ARH)',
#   'Kupuj',
#   '33,00 zł',
#   '35,00 zł',
#   '6,06%',
#   '26,10 zł',
#   'Trigon DM',
#   '31.07.2023',
#   ''],
#  ['CDPROJEKT (CDR)',
#   'Trzymaj',
#   '133,80 zł',
#   '152,00 zł',
#   '13,60%',
#   '164,40 zł',
#   'DM BOŚ',
#   '31.07.2023',
#   ''],
#  ['CCC (CCC)',
#   'Kupuj',
#   '122,50 zł',
#   '63,90 zł',
#   '-47,84%',
#   '49,30 zł',
#   'BM mBank',
#   '27.07.2023',
#   ''],
#  ['CYFRPLSAT (CPS)',
#   'Trzymaj',
#   '11,89 zł',
#   '16,70 zł',
#   '40,45%',
#   '16,20 zł',
#   'DM BOŚ',
#   '26.07.2023',
#   ''],
#  ['STSHOLDING (STH)',
#   'Sprzedaj',
#   '24,60 zł',
#   '24,80 zł',
#   '0,81%',
#   '24,60 zł',
#   'DM BOŚ',
#   '25.07.2023',
#   ''],
#  ['BUDIMEX (BDX)',
#   'Redukuj',
#   '672,50 zł',
#   '376,50 zł',
#   '-44,01%',
#   '443,50 zł',
#   'DM BDM',
#   '25.07.2023',
#   ''],
#  ['RAINBOW (RBW)',
#   'Kupuj',
#   '112,20 zł',
#   '65,00 zł',
#   '-42,07%',
#   '42,90 zł',
#   'Trigon DM',
#   '25.07.2023',
#   ''],
#  ['DADELO (DAD)*',
#   'Kupuj',
#   '20,10 zł',
#   '20,00 zł',
#   '-0,50%',
#   '15,45 zł',
#   'Trigon DM',
#   '24.07.2023',
#   ''],
#  ['MOBRUK (MBR)',
#   'Kupuj',
#   '310,50 zł',
#   '372,00 zł',
#   '19,81%',
#   '271,50 zł',
#   'BM mBank',
#   '24.07.2023',
#   ''],
#  ['FABRITY (FAB)*',
#   'Trzymaj',
#   '37,50 zł',
#   '37,00 zł',
#   '-1,33%',
#   '36,80 zł',
#   'Trigon DM',
#   '24.07.2023',
#   ''],
#  ['VERCOM (VRC)',
#   'Trzymaj',
#   '122,00 zł',
#   '71,70 zł',
#   '-41,23%',
#   '69,80 zł',
#   'DM BOŚ',
#   '24.07.2023',
#   ''],
#  ['DEVELIA (DVL)',
#   'Kupuj',
#   '5,35 zł',
#   '5,50 zł',
#   '2,80%',
#   '4,81 zł',
#   'Trigon DM',
#   '24.07.2023',
#   ''],
#  ['MILLENNIUM (MIL)',
#   'Kupuj',
#   '8,02 zł',
#   '7,86 zł',
#   '-2,00%',
#   '6,61 zł',
#   'DM BOŚ',
#   '22.07.2023',
#   ''],
#  ['11BIT (11B)',
#   'Kupuj',
#   '633,00 zł',
#   '875,00 zł',
#   '38,23%',
#   '713,00 zł',
#   'DM BDM',
#   '21.07.2023',
#   ''],
#  ['FORTE (FTE)',
#   'Akumuluj',
#   '21,60 zł',
#   '31,00 zł',
#   '43,52%',
#   '28,60 zł',
#   'Noble Securities',
#   '20.07.2023',
#   ''],
#  ['NOVAVISGR (NVG)',
#   'Kupuj',
#   '2,37 zł',
#   '3,89 zł',
#   '64,14%',
#   '1,77 zł',
#   'Erste',
#   '19.07.2023',
#   ''],
#  ['TEXT (TXT)',
#   'Trzymaj',
#   '78,00 zł',
#   '137,50 zł',
#   '76,28%',
#   '148,20 zł',
#   'DM BOŚ',
#   '14.07.2023',
#   ''],
#  ['PKNORLEN (PKN)',
#   'Kupuj',
#   '63,45 zł',
#   '95,50 zł',
#   '50,51%',
#   '65,51 zł',
#   'DM BOŚ',
#   '11.07.2023',
#   ''],
#  ['NEUCA (NEU)',
#   'Kupuj',
#   '892,00 zł',
#   '939,00 zł',
#   '5,27%',
#   '764,00 zł',
#   'DM BDM',
#   '10.07.2023',
#   ''],
#  ['VOXEL (VOX)',
#   'Kupuj',
#   '90,00 zł',
#   '73,80 zł',
#   '-18,00%',
#   '48,40 zł',
#   'East Value Research',
#   '10.07.2023',
#   ''],
#  ['ASSECOBS (ABS)',
#   'Kupuj',
#   '56,00 zł',
#   '44,60 zł',
#   '-20,36%',
#   '38,60 zł',
#   'DM BOŚ',
#   '07.07.2023',
#   ''],
#  ['ANSWEAR (ANR)',
#   'Kupuj',
#   '22,65 zł',
#   '48,00 zł',
#   '111,92%',
#   '36,60 zł',
#   'Noble Securities',
#   '07.07.2023',
#   ''],
#  ['KRUK (KRU)',
#   'Kupuj',
#   '437,00 zł',
#   '440,73 zł',
#   '0,85%',
#   '412,20 zł',
#   'BM mBank',
#   '05.07.2023',
#   ''],
#  ['TSGAMES (TEN)',
#   'Kupuj',
#   '82,00 zł',
#   '104,00 zł',
#   '26,83%',
#   '79,35 zł',
#   'DM BDM',
#   '05.07.2023',
#   ''],
#  ['CAPTORTX (CTX)',
#   'Akumuluj',
#   '79,00 zł',
#   '183,60 zł',
#   '132,41%',
#   '146,50 zł',
#   'Noble Securities',
#   '05.07.2023',
#   ''],
#  ['DATAWALK (DAT)*',
#   'Kupuj',
#   '64,60 zł',
#   '122,00 zł',
#   '88,85%',
#   '65,30 zł',
#   'DM BOŚ',
#   '05.07.2023',
#   ''],
#  ['OPONEO.PL (OPN)',
#   'Kupuj',
#   '78,40 zł',
#   '51,20 zł',
#   '-34,69%',
#   '43,10 zł',
#   'East Value Research',
#   '04.07.2023',
#   ''],
#  ['WITTCHEN (WTN)',
#   'Akumuluj',
#   '31,90 zł',
#   '39,50 zł',
#   '23,82%',
#   '36,60 zł',
#   'DM Banku BPS',
#   '03.07.2023',
#   ''],
#  ['HANDLOWY (BHW)',
#   'Trzymaj',
#   '105,00 zł',
#   '80,00 zł',
#   '-23,81%',
#   '87,10 zł',
#   'BM mBank',
#   '30.06.2023',
#   ''],
#  ['SNIEZKA (SKA)*',
#   'Kupuj',
#   '85,00 zł',
#   '92,69 zł',
#   '9,05%',
#   '70,40 zł',
#   'Ipopema Securities',
#   '30.06.2023',
#   ''],
#  ['CAPTORTX (CTX)*',
#   'Kupuj',
#   '79,00 zł',
#   '221,00 zł',
#   '179,75%',
#   '148,00 zł',
#   'Trigon DM',
#   '29.06.2023',
#   ''],
#  ['MOLECURE (MOC)*',
#   'Trzymaj',
#   '14,00 zł',
#   '23,20 zł',
#   '65,71%',
#   '21,00 zł',
#   'Ipopema Securities',
#   '29.06.2023',
#   ''],
#  ['SFD (SFD)*',
#   'Trzymaj',
#   '2,16 zł',
#   '4,54 zł',
#   '110,19%',
#   '4,18 zł',
#   'Ipopema Securities',
#   '29.06.2023',
#   ''],
#  ['SYNEKTIK (SNT)*',
#   'Trzymaj',
#   '141,40 zł',
#   '75,00 zł',
#   '-46,96%',
#   '74,40 zł',
#   'Ipopema Securities',
#   '29.06.2023',
#   ''],
#  ['PEP (PEP)',
#   'Kupuj',
#   '63,20 zł',
#   '96,70 zł',
#   '53,01%',
#   '82,70 zł',
#   'Trigon DM',
#   '26.06.2023',
#   ''],
#  ['CYBERFLKS (CBF)*',
#   'Kupuj',
#   '120,00 zł',
#   '88,60 zł',
#   '-26,17%',
#   '68,80 zł',
#   'Trigon DM',
#   '26.06.2023',
#   ''],
#  ['ASSECOSEE (ASE)',
#   'Trzymaj',
#   '49,90 zł',
#   '50,00 zł',
#   '0,20%',
#   '47,30 zł',
#   'DM BOŚ',
#   '26.06.2023',
#   ''],
#  ['KGL (KGL)*',
#   'Akumuluj',
#   '15,60 zł',
#   '16,60 zł',
#   '6,41%',
#   '14,50 zł',
#   'Millennium DM',
#   '20.06.2023',
#   ''],
#  ['BENEFIT (BFT)',
#   'Kupuj',
#   '2 790,00 zł',
#   '1 600,00 zł',
#   '-42,65%',
#   '1 480,00 zł',
#   'DM BOŚ',
#   '19.06.2023',
#   ''],
#  ['ULTGAMES (ULG)*',
#   'Kupuj',
#   '11,40 zł',
#   '17,00 zł',
#   '49,12%',
#   '12,85 zł',
#   'Ipopema Securities',
#   '19.06.2023',
#   ''],
#  ['AGORA (AGO)*',
#   'Akumuluj',
#   '10,90 zł',
#   '9,30 zł',
#   '-14,68%',
#   '8,10 zł',
#   'Millennium DM',
#   '16.06.2023',
#   '']]

# %%
print("\n\nRekomendacje\n") 
print(pd.DataFrame(tabela.tables[0])) #converting table to dataframe
# Out:
# Rekomendacje
#
#                    0         1              2              3                      4                  5                    6           7       8
# 0             Spółka    Rodzaj  Cena aktualna  Cena docelowa  Potencjał zmiany ceny  Cena w dniu publ.           Instytucja  Data publ.  Raport
# 1     AILLERON (ALL)     Kupuj       17,62 zł       23,10 zł                 31,10%           17,06 zł     Noble Securities  13.06.2024
# 2     RAINBOW (RBW)*     Kupuj      112,20 zł      155,00 zł                 38,15%          103,00 zł       BM Banku Pekao  12.06.2024
# 3    SKARBIEC (SKH)*     Kupuj       22,90 zł       34,00 zł                 48,47%           22,70 zł       BM Banku Pekao  11.06.2024
# 4     INTERBUD (ITB)     Kupuj        3,02 zł        6,70 zł                121,85%            3,66 zł  East Value Research  11.06.2024
# ..               ...       ...            ...            ...                    ...                ...                  ...         ...     ...
# 337  ASSECOSEE (ASE)   Trzymaj       49,90 zł       50,00 zł                  0,20%           47,30 zł               DM BOŚ  26.06.2023
# 338       KGL (KGL)*  Akumuluj       15,60 zł       16,60 zł                  6,41%           14,50 zł        Millennium DM  20.06.2023
# 339    BENEFIT (BFT)     Kupuj    2 790,00 zł    1 600,00 zł                -42,65%        1 480,00 zł               DM BOŚ  19.06.2023
# 340  ULTGAMES (ULG)*     Kupuj       11,40 zł       17,00 zł                 49,12%           12,85 zł   Ipopema Securities  19.06.2023
# 341     AGORA (AGO)*  Akumuluj       10,90 zł        9,30 zł                -14,68%            8,10 zł        Millennium DM  16.06.2023
#
# [342 rows x 9 columns]

# %%
rec= pd.DataFrame(tabela.tables[0])

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.expand_frame_repr', False)  # Prevent line breaks in columns
display(rec)
# Out:
#                    0         1              2              3                      4                  5                    6           7       8
# 0             Spółka    Rodzaj  Cena aktualna  Cena docelowa  Potencjał zmiany ceny  Cena w dniu publ.           Instytucja  Data publ.  Raport
# 1     AILLERON (ALL)     Kupuj       17,62 zł       23,10 zł                 31,10%           17,06 zł     Noble Securities  13.06.2024
# 2     RAINBOW (RBW)*     Kupuj      112,20 zł      155,00 zł                 38,15%          103,00 zł       BM Banku Pekao  12.06.2024
# 3    SKARBIEC (SKH)*     Kupuj       22,90 zł       34,00 zł                 48,47%           22,70 zł       BM Banku Pekao  11.06.2024
# 4     INTERBUD (ITB)     Kupuj        3,02 zł        6,70 zł                121,85%            3,66 zł  East Value Research  11.06.2024
# ..               ...       ...            ...            ...                    ...                ...                  ...         ...     ...
# 337  ASSECOSEE (ASE)   Trzymaj       49,90 zł       50,00 zł                  0,20%           47,30 zł               DM BOŚ  26.06.2023
# 338       KGL (KGL)*  Akumuluj       15,60 zł       16,60 zł                  6,41%           14,50 zł        Millennium DM  20.06.2023
# 339    BENEFIT (BFT)     Kupuj    2 790,00 zł    1 600,00 zł                -42,65%        1 480,00 zł               DM BOŚ  19.06.2023
# 340  ULTGAMES (ULG)*     Kupuj       11,40 zł       17,00 zł                 49,12%           12,85 zł   Ipopema Securities  19.06.2023
# 341     AGORA (AGO)*  Akumuluj       10,90 zł        9,30 zł                -14,68%            8,10 zł        Millennium DM  16.06.2023
#
# [342 rows x 9 columns]

# %%
rec.describe()
# Out:
#                    0      1         2         3      4         5       6           7    8
# count            342    342       342       342    342       342     342         342  342
# unique           183     10       146       299    327       313      15         170    2
# top     TORPOL (TOR)  Kupuj  90,00 zł  25,00 zł  6,67%  61,00 zł  DM BOŚ  04.10.2023
# freq               7    208        12         4      3         3      83          14  341

# %%
rec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       342 non-null    object
#  1   1       342 non-null    object
#  2   2       342 non-null    object
#  3   3       342 non-null    object
#  4   4       342 non-null    object
#  5   5       342 non-null    object
#  6   6       342 non-null    object
#  7   7       342 non-null    object
#  8   8       342 non-null    object
# dtypes: object(9)
# memory usage: 24.2+ KB

# %%
rec.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# 7    object
# 8    object
# dtype: object

# %%
rec.columns = rec.iloc[0]
rec = rec.drop(rec.index[0])
rec.head()
# Out:
# 0           Spółka Rodzaj Cena aktualna Cena docelowa Potencjał zmiany ceny Cena w dniu publ.           Instytucja  Data publ. Raport
# 1   AILLERON (ALL)  Kupuj      17,62 zł      23,10 zł                31,10%          17,06 zł     Noble Securities  13.06.2024
# 2   RAINBOW (RBW)*  Kupuj     112,20 zł     155,00 zł                38,15%         103,00 zł       BM Banku Pekao  12.06.2024
# 3  SKARBIEC (SKH)*  Kupuj      22,90 zł      34,00 zł                48,47%          22,70 zł       BM Banku Pekao  11.06.2024
# 4   INTERBUD (ITB)  Kupuj       3,02 zł       6,70 zł               121,85%           3,66 zł  East Value Research  11.06.2024
# 5     ENTER (ENT)*  Kupuj      64,70 zł      77,50 zł                19,78%          61,00 zł               DM BDM  10.06.2024

# %%
#function to clean prices

def clean_prices(rec_clean):
    #dropping the 'zl'
    rec_clean = rec_clean.astype(str).str.replace('zł','')
    #cleaning spaces
    rec_clean= rec_clean.astype(str).str.replace(' ','')
    #changing comma to dot
    rec_clean = rec_clean.astype(str).str.replace(',','.')
    #changing dtype to float, unless empty
    rec_clean = rec_clean.apply(lambda x: float(x) if x else None)
    return rec_clean

# %%
rec['Cena aktualna']= clean_prices(rec['Cena aktualna'])

# %%
print(rec['Cena aktualna'])
# Out:
# 1        17.62
# 2       112.20
# 3        22.90
# 4         3.02
# 5        64.70
#         ...
# 337      49.90
# 338      15.60
# 339    2790.00
# 340      11.40
# 341      10.90
# Name: Cena aktualna, Length: 341, dtype: float64

# %%
rec['Cena docelowa']= clean_prices(rec['Cena docelowa'])
rec['Cena w dniu publ.']= clean_prices(rec['Cena w dniu publ.'])

# %%
rec['Data publ.']= pd.to_datetime(rec['Data publ.'], dayfirst= True) #converting date to pandas datetime object
rec['Potencjał zmiany ceny']= rec['Potencjał zmiany ceny'].astype(str).str.replace('%','').str.replace(',','.').apply(lambda x: float(x) if x else None).apply(lambda x: x/100 if x else None)

# %%
rec.head()
# Out:
# 0           Spółka Rodzaj  Cena aktualna  Cena docelowa  Potencjał zmiany ceny  Cena w dniu publ.           Instytucja Data publ. Raport
# 1   AILLERON (ALL)  Kupuj          17.62           23.1                 0.3110              17.06     Noble Securities 2024-06-13
# 2   RAINBOW (RBW)*  Kupuj         112.20          155.0                 0.3815             103.00       BM Banku Pekao 2024-06-12
# 3  SKARBIEC (SKH)*  Kupuj          22.90           34.0                 0.4847              22.70       BM Banku Pekao 2024-06-11
# 4   INTERBUD (ITB)  Kupuj           3.02            6.7                 1.2185               3.66  East Value Research 2024-06-11
# 5     ENTER (ENT)*  Kupuj          64.70           77.5                 0.1978              61.00               DM BDM 2024-06-10

# %%
print(rec)
# Out:
# 0             Spółka    Rodzaj  Cena aktualna  Cena docelowa  Potencjał zmiany ceny  Cena w dniu publ.           Instytucja Data publ. Raport
# 1     AILLERON (ALL)     Kupuj          17.62           23.1                 0.3110              17.06     Noble Securities 2024-06-13
# 2     RAINBOW (RBW)*     Kupuj         112.20          155.0                 0.3815             103.00       BM Banku Pekao 2024-06-12
# 3    SKARBIEC (SKH)*     Kupuj          22.90           34.0                 0.4847              22.70       BM Banku Pekao 2024-06-11
# 4     INTERBUD (ITB)     Kupuj           3.02            6.7                 1.2185               3.66  East Value Research 2024-06-11
# 5       ENTER (ENT)*     Kupuj          64.70           77.5                 0.1978              61.00               DM BDM 2024-06-10
# ..               ...       ...            ...            ...                    ...                ...                  ...        ...    ...
# 337  ASSECOSEE (ASE)   Trzymaj          49.90           50.0                 0.0020              47.30               DM BOŚ 2023-06-26
# 338       KGL (KGL)*  Akumuluj          15.60           16.6                 0.0641              14.50        Millennium DM 2023-06-20
# 339    BENEFIT (BFT)     Kupuj        2790.00         1600.0                -0.4265            1480.00               DM BOŚ 2023-06-19
# 340  ULTGAMES (ULG)*     Kupuj          11.40           17.0                 0.4912              12.85   Ipopema Securities 2023-06-19
# 341     AGORA (AGO)*  Akumuluj          10.90            9.3                -0.1468               8.10        Millennium DM 2023-06-16
#
# [341 rows x 9 columns]
