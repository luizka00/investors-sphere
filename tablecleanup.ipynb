# %% [markdown]
# Importing data from a website in a form of cvs file:

# %%
# Library for opening url and creating 
# requests
import urllib.request
import pandas as pd
# pretty-print python data structures
from pprint import pprint
# for parsing all the tables present 
# on the website
from html_table_parser.parser import HTMLTableParser
import matplotlib.pyplot as plt

# %% [markdown]
# function to read a website:

# %%
def get_content(url):

    #making request to the website
    request = urllib.request.Request(url=url)
    f = urllib.request.urlopen(request)

    #reading contents of the website
    return f.read()

# %%
si_content= get_content('https://strefainwestorow.pl/rekomendacje/lista-rekomendacji/wszystkie').decode('utf-8') #defining html content from this link

tabela = HTMLTableParser()

tabela.feed(si_content)

# %%
pprint(tabela.tables[0])
# Out:
# [['Spółka',
#   'Rodzaj',
#   'Cena aktualna',
#   'Cena docelowa',
#   'Potencjał zmiany ceny',
#   'Cena w dniu publ.',
#   'Instytucja',
#   'Data publ.',
#   'Raport'],
#  ['PEPCO (PCO)',
#   'Trzymaj',
#   '22,25 zł',
#   '26,50 zł',
#   '19,10%',
#   '22,35 zł',
#   'Trigon DM',
#   '25.06.2024',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 880,00 zł',
#   '23 500,00 zł',
#   '39,22%',
#   '16 880,00 zł',
#   'Trigon DM',
#   '24.06.2024',
#   ''],
#  ['SELVITA (SLV)',
#   'Akumuluj',
#   '67,30 zł',
#   '74,60 zł',
#   '10,85%',
#   '63,70 zł',
#   'Noble Securities',
#   '17.06.2024',
#   ''],
#  ['AILLERON (ALL)',
#   'Kupuj',
#   '17,40 zł',
#   '23,10 zł',
#   '32,76%',
#   '17,06 zł',
#   'Noble Securities',
#   '13.06.2024',
#   ''],
#  ['RAINBOW (RBW)*',
#   'Kupuj',
#   '113,00 zł',
#   '155,00 zł',
#   '37,17%',
#   '103,00 zł',
#   'BM Banku Pekao',
#   '12.06.2024',
#   ''],
#  ['SKARBIEC (SKH)*',
#   'Kupuj',
#   '24,20 zł',
#   '34,00 zł',
#   '40,50%',
#   '22,70 zł',
#   'BM Banku Pekao',
#   '11.06.2024',
#   ''],
#  ['INTERBUD (ITB)',
#   'Kupuj',
#   '2,70 zł',
#   '6,70 zł',
#   '148,15%',
#   '3,66 zł',
#   'East Value Research',
#   '11.06.2024',
#   ''],
#  ['ENTER (ENT)*',
#   'Kupuj',
#   '67,20 zł',
#   '77,50 zł',
#   '15,33%',
#   '61,00 zł',
#   'DM BDM',
#   '10.06.2024',
#   ''],
#  ['BIOMAXIMA (BMX)*',
#   'Kupuj',
#   '15,45 zł',
#   '22,90 zł',
#   '48,22%',
#   '14,55 zł',
#   'DM BDM',
#   '05.06.2024',
#   ''],
#  ['XTPL (XTP)',
#   'Kupuj',
#   '125,40 zł',
#   '167,00 zł',
#   '33,17%',
#   '126,20 zł',
#   'Trigon DM',
#   '03.06.2024',
#   ''],
#  ['STALPROFI (STF)*',
#   'Kupuj',
#   '9,32 zł',
#   '10,64 zł',
#   '14,16%',
#   '8,90 zł',
#   'BM Banku Pekao',
#   '03.06.2024',
#   ''],
#  ['PHOTON (PEN)*',
#   'Wycena',
#   '7,44 zł',
#   '6,82 zł',
#   '-8,33%',
#   '7,70 zł',
#   'Noble Securities',
#   '31.05.2024',
#   ''],
#  ['NOVAVISGR (NVG)',
#   'Kupuj',
#   '2,26 zł',
#   '4,00 zł',
#   '76,99%',
#   '2,07 zł',
#   'East Value Research',
#   '31.05.2024',
#   ''],
#  ['ENEA (ENA)',
#   'Trzymaj',
#   '9,42 zł',
#   '11,63 zł',
#   '23,53%',
#   '10,24 zł',
#   'Trigon DM',
#   '29.05.2024',
#   ''],
#  ['MOBRUK (MBR)',
#   'Akumuluj',
#   '317,00 zł',
#   '375,80 zł',
#   '18,55%',
#   '318,50 zł',
#   'Noble Securities',
#   '28.05.2024',
#   ''],
#  ['MLPGROUP (MLG)*',
#   'Kupuj',
#   '83,00 zł',
#   '110,00 zł',
#   '32,53%',
#   '80,00 zł',
#   'BM PKO BP',
#   '28.05.2024',
#   ''],
#  ['11BIT (11B)',
#   'Kupuj',
#   '642,00 zł',
#   '952,60 zł',
#   '48,38%',
#   '585,00 zł',
#   'Noble Securities',
#   '27.05.2024',
#   ''],
#  ['RYVU (RVU)',
#   'Trzymaj',
#   '50,90 zł',
#   '75,50 zł',
#   '48,33%',
#   '53,40 zł',
#   'Noble Securities',
#   '24.05.2024',
#   ''],
#  ['ATENDE (ATD)*',
#   'Kupuj',
#   '3,00 zł',
#   '3,70 zł',
#   '23,33%',
#   '2,90 zł',
#   'BM Banku Pekao',
#   '24.05.2024',
#   ''],
#  ['COMP (CMP)',
#   'Kupuj',
#   '100,50 zł',
#   '132,00 zł',
#   '31,34%',
#   '110,00 zł',
#   'DM BOŚ',
#   '24.05.2024',
#   ''],
#  ['SUNEX (SNX)*',
#   'Kupuj',
#   '10,40 zł',
#   '12,37 zł',
#   '18,94%',
#   '10,52 zł',
#   'Ipopema Securities',
#   '24.05.2024',
#   ''],
#  ['TSGAMES (TEN)',
#   'Kupuj',
#   '84,55 zł',
#   '118,00 zł',
#   '39,56%',
#   '93,80 zł',
#   'DM BDM',
#   '22.05.2024',
#   ''],
#  ['KINOPOL (KPL)*',
#   'Kupuj',
#   '17,70 zł',
#   '20,05 zł',
#   '13,28%',
#   '14,85 zł',
#   'DM BDM',
#   '21.05.2024',
#   ''],
#  ['TORPOL (TOR)',
#   'Trzymaj',
#   '36,30 zł',
#   '35,00 zł',
#   '-3,58%',
#   '35,25 zł',
#   'Noble Securities',
#   '21.05.2024',
#   ''],
#  ['TAURONPE (TPE)',
#   'Kupuj',
#   '3,91 zł',
#   '3,94 zł',
#   '0,77%',
#   '3,93 zł',
#   'Trigon DM',
#   '20.05.2024',
#   ''],
#  ['RELPOL (RLP)*',
#   'Trzymaj',
#   '5,70 zł',
#   '6,25 zł',
#   '9,65%',
#   '6,16 zł',
#   'DM BDM',
#   '20.05.2024',
#   ''],
#  ['CCC (CCC)',
#   'Kupuj',
#   '123,00 zł',
#   '160,00 zł',
#   '30,08%',
#   '133,20 zł',
#   'Trigon DM',
#   '20.05.2024',
#   ''],
#  ['PGE (PGE)',
#   'Kupuj',
#   '6,91 zł',
#   '8,90 zł',
#   '28,87%',
#   '7,74 zł',
#   'Trigon DM',
#   '20.05.2024',
#   ''],
#  ['VOXEL (VOX)',
#   'Kupuj',
#   '93,20 zł',
#   '106,60 zł',
#   '14,38%',
#   '92,00 zł',
#   'DM BDM',
#   '20.05.2024',
#   ''],
#  ['ELEKTROTI (ELT)*',
#   'Akumuluj',
#   '34,80 zł',
#   '31,00 zł',
#   '-10,92%',
#   '27,85 zł',
#   'DM BDM',
#   '20.05.2024',
#   ''],
#  ['ELQ (ELQ)',
#   'Kupuj',
#   '3,20 zł',
#   '3,90 zł',
#   '21,88%',
#   '3,01 zł',
#   'East Value Research',
#   '20.05.2024',
#   ''],
#  ['PEPCO (PCO)',
#   'Trzymaj',
#   '22,25 zł',
#   '21,90 zł',
#   '-1,57%',
#   '21,23 zł',
#   'Noble Securities',
#   '17.05.2024',
#   ''],
#  ['ACTION (ACT)*',
#   'Kupuj',
#   '20,80 zł',
#   '25,00 zł',
#   '20,19%',
#   '20,35 zł',
#   'DM BOŚ',
#   '17.05.2024',
#   ''],
#  ['GRUPAAZOTY (ATT)',
#   'Sprzedaj',
#   '20,88 zł',
#   '20,00 zł',
#   '-4,21%',
#   '24,64 zł',
#   'DM BOŚ',
#   '17.05.2024',
#   ''],
#  ['TORPOL (TOR)',
#   'Kupuj',
#   '36,30 zł',
#   '35,00 zł',
#   '-3,58%',
#   '32,10 zł',
#   'Noble Securities',
#   '15.05.2024',
#   ''],
#  ['RAINBOW (RBW)',
#   'Kupuj',
#   '113,00 zł',
#   '136,60 zł',
#   '20,88%',
#   '107,00 zł',
#   'East Value Research',
#   '14.05.2024',
#   ''],
#  ['VOTUM (VOT)*',
#   'Kupuj',
#   '33,60 zł',
#   '66,90 zł',
#   '99,11%',
#   '43,65 zł',
#   'DM BOŚ',
#   '13.05.2024',
#   ''],
#  ['CYFRPLSAT (CPS)',
#   'Kupuj',
#   '12,18 zł',
#   '13,39 zł',
#   '9,93%',
#   '11,47 zł',
#   'DM BDM',
#   '10.05.2024',
#   ''],
#  ['RAINBOW (RBW)*',
#   'Kupuj',
#   '113,00 zł',
#   '120,00 zł',
#   '6,19%',
#   '94,90 zł',
#   'BM Banku Pekao',
#   '10.05.2024',
#   ''],
#  ['OPONEO.PL (OPN)*',
#   'Trzymaj',
#   '76,20 zł',
#   '63,50 zł',
#   '-16,67%',
#   '61,00 zł',
#   'BM PKO BP',
#   '10.05.2024',
#   ''],
#  ['UNIBEP (UNI)*',
#   'Wycena',
#   '9,38 zł',
#   '12,00 zł',
#   '27,93%',
#   '9,64 zł',
#   'Noble Securities',
#   '09.05.2024',
#   ''],
#  ['QUERCUS (QRS)*',
#   'Kupuj',
#   '6,20 zł',
#   '7,50 zł',
#   '20,97%',
#   '6,58 zł',
#   'BM Banku Pekao',
#   '09.05.2024',
#   ''],
#  ['ARTIFEX (ART)*',
#   'Trzymaj',
#   '22,80 zł',
#   '26,00 zł',
#   '14,04%',
#   '26,50 zł',
#   'DM BDM',
#   '08.05.2024',
#   ''],
#  ['IMS (IMS)*',
#   'Akumuluj',
#   '4,38 zł',
#   '5,00 zł',
#   '14,16%',
#   '4,36 zł',
#   'Millennium DM',
#   '08.05.2024',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 880,00 zł',
#   '23 300,00 zł',
#   '38,03%',
#   '16 530,00 zł',
#   'BM mBank',
#   '07.05.2024',
#   ''],
#  ['HANDLOWY (BHW)',
#   'Sprzedaj',
#   '109,00 zł',
#   '107,00 zł',
#   '-1,83%',
#   '111,00 zł',
#   'BM mBank',
#   '07.05.2024',
#   ''],
#  ['ABPL (ABE)',
#   'Kupuj',
#   '104,00 zł',
#   '96,60 zł',
#   '-7,12%',
#   '89,80 zł',
#   'DM BOŚ',
#   '07.05.2024',
#   ''],
#  ['INTERCARS (CAR)',
#   'Trzymaj',
#   '547,00 zł',
#   '525,00 zł',
#   '-4,02%',
#   '539,00 zł',
#   'DM BOŚ',
#   '07.05.2024',
#   ''],
#  ['WARIMPEX (WXF)',
#   'Wycena',
#   '3,69 zł',
#   '9,49 zł',
#   '157,18%',
#   '3,72 zł',
#   'East Value Research',
#   '07.05.2024',
#   ''],
#  ['SONEL (SON)*',
#   'Wycena',
#   '18,00 zł',
#   '15,78 zł',
#   '-12,33%',
#   '14,90 zł',
#   'Noble Securities',
#   '06.05.2024',
#   ''],
#  ['SELVITA (SLV)',
#   'Trzymaj',
#   '67,30 zł',
#   '62,70 zł',
#   '-6,84%',
#   '70,60 zł',
#   'DM BOŚ',
#   '06.05.2024',
#   ''],
#  ['PGE (PGE)',
#   'Sprzedaj',
#   '6,91 zł',
#   '5,60 zł',
#   '-18,91%',
#   '6,18 zł',
#   'DM BOŚ',
#   '05.05.2024',
#   ''],
#  ['TAURONPE (TPE)',
#   'Sprzedaj',
#   '3,91 zł',
#   '2,60 zł',
#   '-33,50%',
#   '2,93 zł',
#   'DM BOŚ',
#   '05.05.2024',
#   ''],
#  ['ASBIS (ASB)',
#   'Kupuj',
#   '24,24 zł',
#   '38,60 zł',
#   '59,24%',
#   '24,60 zł',
#   'DM BOŚ',
#   '05.05.2024',
#   ''],
#  ['DINOPL (DNP)',
#   'Trzymaj',
#   '416,10 zł',
#   '382,50 zł',
#   '-8,07%',
#   '386,70 zł',
#   'DM BOŚ',
#   '05.05.2024',
#   ''],
#  ['TORPOL (TOR)',
#   'Akumuluj',
#   '36,30 zł',
#   '35,60 zł',
#   '-1,93%',
#   '31,60 zł',
#   'DM BDM',
#   '02.05.2024',
#   ''],
#  ['CLOUD (CLD)*',
#   'Trzymaj',
#   '76,00 zł',
#   '75,00 zł',
#   '-1,32%',
#   '70,60 zł',
#   'DM BOŚ',
#   '30.04.2024',
#   ''],
#  ['STALPROFI (STF)*',
#   'Kupuj',
#   '9,32 zł',
#   '9,85 zł',
#   '5,69%',
#   '8,26 zł',
#   'BM Banku Pekao',
#   '30.04.2024',
#   ''],
#  ['VOXEL (VOX)*',
#   'Kupuj',
#   '93,20 zł',
#   '103,00 zł',
#   '10,52%',
#   '92,20 zł',
#   'DM BOŚ',
#   '29.04.2024',
#   ''],
#  ['MABION (MAB)*',
#   'Wycena',
#   '16,98 zł',
#   '19,00 zł',
#   '11,90%',
#   '16,24 zł',
#   'Noble Securities',
#   '29.04.2024',
#   ''],
#  ['FORTE (FTE)',
#   'Trzymaj',
#   '21,90 zł',
#   '21,10 zł',
#   '-3,65%',
#   '23,00 zł',
#   'DM BOŚ',
#   '29.04.2024',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 880,00 zł',
#   '21 047,00 zł',
#   '24,69%',
#   '15 550,00 zł',
#   'DM BOŚ',
#   '29.04.2024',
#   ''],
#  ['CCC (CCC)',
#   'Kupuj',
#   '123,00 zł',
#   '108,80 zł',
#   '-11,54%',
#   '87,50 zł',
#   'DM BOŚ',
#   '29.04.2024',
#   ''],
#  ['ARCHICOM (ARH)',
#   'Kupuj',
#   '36,00 zł',
#   '40,00 zł',
#   '11,11%',
#   '34,00 zł',
#   'Trigon DM',
#   '25.04.2024',
#   ''],
#  ['DADELO (DAD)*',
#   'Kupuj',
#   '19,70 zł',
#   '23,00 zł',
#   '16,75%',
#   '17,25 zł',
#   'Trigon DM',
#   '25.04.2024',
#   ''],
#  ['ECHO (ECH)',
#   'Kupuj',
#   '4,85 zł',
#   '6,00 zł',
#   '23,71%',
#   '4,91 zł',
#   'Trigon DM',
#   '25.04.2024',
#   ''],
#  ['AILLERON (ALL)*',
#   'Kupuj',
#   '17,40 zł',
#   '25,00 zł',
#   '43,68%',
#   '15,70 zł',
#   'Trigon DM',
#   '25.04.2024',
#   ''],
#  ['FABRITY (FAB)*',
#   'Trzymaj',
#   '34,00 zł',
#   '39,00 zł',
#   '14,71%',
#   '36,80 zł',
#   'Trigon DM',
#   '25.04.2024',
#   ''],
#  ['MFO (MFO)*',
#   'Kupuj',
#   '32,10 zł',
#   '49,30 zł',
#   '53,58%',
#   '33,60 zł',
#   'Trigon DM',
#   '25.04.2024',
#   ''],
#  ['SELENAFM (SEL)*',
#   'Kupuj',
#   '36,10 zł',
#   '46,40 zł',
#   '28,53%',
#   '32,60 zł',
#   'Trigon DM',
#   '25.04.2024',
#   ''],
#  ['PZU (PZU)',
#   'Kupuj',
#   '50,72 zł',
#   '58,30 zł',
#   '14,94%',
#   '50,68 zł',
#   'Trigon DM',
#   '22.04.2024',
#   ''],
#  ['ZUE (ZUE)*',
#   'Trzymaj',
#   '10,80 zł',
#   '11,10 zł',
#   '2,78%',
#   '10,90 zł',
#   'DM BDM',
#   '22.04.2024',
#   ''],
#  ['CCC (CCC)',
#   'Kupuj',
#   '123,00 zł',
#   '120,00 zł',
#   '-2,44%',
#   '82,60 zł',
#   'Trigon DM',
#   '22.04.2024',
#   ''],
#  ['ATMGRUPA (ATG)*',
#   'Kupuj',
#   '4,46 zł',
#   '4,91 zł',
#   '10,09%',
#   '3,20 zł',
#   'DM BDM',
#   '22.04.2024',
#   ''],
#  ['BIOTON (BIO)*',
#   'Wycena',
#   '3,47 zł',
#   '4,46 zł',
#   '28,53%',
#   '3,50 zł',
#   'Noble Securities',
#   '18.04.2024',
#   ''],
#  ['KGHM (KGH)',
#   'Kupuj',
#   '150,95 zł',
#   '185,00 zł',
#   '22,56%',
#   '142,40 zł',
#   'DM BOŚ',
#   '18.04.2024',
#   ''],
#  ['ORANGEPL (OPL)',
#   'Kupuj',
#   '7,65 zł',
#   '9,30 zł',
#   '21,51%',
#   '7,78 zł',
#   'DM BOŚ',
#   '17.04.2024',
#   ''],
#  ['BOGDANKA (LWB)',
#   'Sprzedaj',
#   '29,94 zł',
#   '25,00 zł',
#   '-16,50%',
#   '32,72 zł',
#   'DM BOŚ',
#   '17.04.2024',
#   ''],
#  ['CAPTORTX (CTX)',
#   'Kupuj',
#   '78,60 zł',
#   '131,10 zł',
#   '66,79%',
#   '79,00 zł',
#   'Noble Securities',
#   '16.04.2024',
#   ''],
#  ['TSGAMES (TEN)',
#   'Trzymaj',
#   '84,55 zł',
#   '106,00 zł',
#   '25,37%',
#   '96,10 zł',
#   'DM BOŚ',
#   '15.04.2024',
#   ''],
#  ['SYGNITY (SGN)*',
#   'Sprzedaj',
#   '62,40 zł',
#   '35,80 zł',
#   '-42,63%',
#   '64,00 zł',
#   'BM mBank',
#   '15.04.2024',
#   ''],
#  ['HUUUGE (HUG)',
#   'Kupuj',
#   '23,30 zł',
#   '35,20 zł',
#   '51,07%',
#   '26,40 zł',
#   'DM BDM',
#   '15.04.2024',
#   ''],
#  ['JSW (JSW)',
#   'Sprzedaj',
#   '29,60 zł',
#   '30,00 zł',
#   '1,35%',
#   '35,34 zł',
#   'DM BOŚ',
#   '15.04.2024',
#   ''],
#  ['ATENDE (ATD)*',
#   'Kupuj',
#   '3,00 zł',
#   '4,10 zł',
#   '36,67%',
#   '2,93 zł',
#   'BM Banku Pekao',
#   '15.04.2024',
#   ''],
#  ['IFIRMA (IFI)*',
#   'Neutralna',
#   '23,40 zł',
#   '21,40 zł',
#   '-8,55%',
#   '22,20 zł',
#   'Millennium DM',
#   '12.04.2024',
#   ''],
#  ['TOYA (TOA)*',
#   'Wycena',
#   '8,28 zł',
#   '11,50 zł',
#   '38,89%',
#   '7,14 zł',
#   'Noble Securities',
#   '11.04.2024',
#   ''],
#  ['ORANGEPL (OPL)',
#   'Akumuluj',
#   '7,65 zł',
#   '9,00 zł',
#   '17,59%',
#   '8,02 zł',
#   'DM BDM',
#   '10.04.2024',
#   ''],
#  ['BRAND24 (B24)*',
#   'Wycena',
#   '46,90 zł',
#   '56,20 zł',
#   '19,83%',
#   '48,80 zł',
#   'DM BOŚ',
#   '09.04.2024',
#   ''],
#  ['VOXEL (VOX)*',
#   'Kupuj',
#   '93,20 zł',
#   '97,70 zł',
#   '4,83%',
#   '93,20 zł',
#   'DM BOŚ',
#   '08.04.2024',
#   ''],
#  ['MCI (MCI)*',
#   'Wycena',
#   '26,50 zł',
#   '40,70 zł',
#   '53,58%',
#   '25,10 zł',
#   'Noble Securities',
#   '05.04.2024',
#   ''],
#  ['TORPOL (TOR)',
#   'Redukuj',
#   '36,30 zł',
#   '35,50 zł',
#   '-2,20%',
#   '35,00 zł',
#   'Noble Securities',
#   '03.04.2024',
#   ''],
#  ['BUDIMEX (BDX)',
#   'Sprzedaj',
#   '695,50 zł',
#   '630,00 zł',
#   '-9,42%',
#   '700,00 zł',
#   'Trigon DM',
#   '02.04.2024',
#   ''],
#  ['ASSECOSEE (ASE)',
#   'Trzymaj',
#   '51,00 zł',
#   '55,00 zł',
#   '7,84%',
#   '50,00 zł',
#   'DM BOŚ',
#   '28.03.2024',
#   ''],
#  ['ASSECOBS (ABS)',
#   'Trzymaj',
#   '62,20 zł',
#   '58,00 zł',
#   '-6,75%',
#   '51,80 zł',
#   'DM BOŚ',
#   '28.03.2024',
#   ''],
#  ['FERRO (FRO)*',
#   'Kupuj',
#   '38,70 zł',
#   '39,30 zł',
#   '1,55%',
#   '33,50 zł',
#   'DM BOŚ',
#   '28.03.2024',
#   ''],
#  ['ASBIS (ASB)',
#   'Wycena',
#   '24,24 zł',
#   '61,00 zł',
#   '151,65%',
#   '24,80 zł',
#   'Argus Research',
#   '27.03.2024',
#   ''],
#  ['SEKO (SEK)*',
#   'Wycena',
#   '11,70 zł',
#   '18,90 zł',
#   '61,54%',
#   '12,90 zł',
#   'DM BOŚ',
#   '27.03.2024',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 880,00 zł',
#   '20 000,00 zł',
#   '18,48%',
#   '13 660,00 zł',
#   'Trigon DM',
#   '26.03.2024',
#   ''],
#  ['MURAPOL (MUR)',
#   'Kupuj',
#   '37,84 zł',
#   '50,00 zł',
#   '32,14%',
#   '41,37 zł',
#   'Trigon DM',
#   '25.03.2024',
#   ''],
#  ['DINOPL (DNP)',
#   'Akumuluj',
#   '416,10 zł',
#   '445,10 zł',
#   '6,97%',
#   '415,00 zł',
#   'Noble Securities',
#   '22.03.2024',
#   ''],
#  ['EUROCASH (EUR)',
#   'Trzymaj',
#   '13,20 zł',
#   '15,70 zł',
#   '18,94%',
#   '14,71 zł',
#   'Noble Securities',
#   '22.03.2024',
#   ''],
#  ['MARVIPOL (MVP)*',
#   'Kupuj',
#   '7,16 zł',
#   '11,15 zł',
#   '55,73%',
#   '8,26 zł',
#   'Ipopema Securities',
#   '20.03.2024',
#   ''],
#  ['AMBRA (AMB)*',
#   'Kupuj',
#   '27,20 zł',
#   '32,20 zł',
#   '18,38%',
#   '27,60 zł',
#   'Millennium DM',
#   '18.03.2024',
#   ''],
#  ['RAINBOW (RBW)',
#   'Kupuj',
#   '113,00 zł',
#   '105,00 zł',
#   '-7,08%',
#   '76,40 zł',
#   'Trigon DM',
#   '14.03.2024',
#   ''],
#  ['TORPOL (TOR)',
#   'Kupuj',
#   '36,30 zł',
#   '45,00 zł',
#   '23,97%',
#   '34,50 zł',
#   'BM Banku Pekao',
#   '14.03.2024',
#   ''],
#  ['SYNEKTIK (SNT)',
#   'Kupuj',
#   '132,60 zł',
#   '180,60 zł',
#   '36,20%',
#   '127,00 zł',
#   'Trigon DM',
#   '11.03.2024',
#   ''],
#  ['CDPROJEKT (CDR)',
#   'Kupuj',
#   '143,80 zł',
#   '192,80 zł',
#   '34,08%',
#   '107,75 zł',
#   'Noble Securities',
#   '08.03.2024',
#   ''],
#  ['CLNPHARMA (CLN)',
#   'Kupuj',
#   '15,64 zł',
#   '25,50 zł',
#   '63,04%',
#   '14,80 zł',
#   'Noble Securities',
#   '08.03.2024',
#   ''],
#  ['SNIEZKA (SKA)',
#   'Kupuj',
#   '89,40 zł',
#   '93,10 zł',
#   '4,14%',
#   '84,80 zł',
#   'DM BDM',
#   '08.03.2024',
#   ''],
#  ['MERCOR (MCR)*',
#   'Trzymaj',
#   '24,80 zł',
#   '26,40 zł',
#   '6,45%',
#   '23,20 zł',
#   'BM Banku Pekao',
#   '07.03.2024',
#   ''],
#  ['RAINBOW (RBW)',
#   'Kupuj',
#   '113,00 zł',
#   '92,40 zł',
#   '-18,23%',
#   '72,60 zł',
#   'East Value Research',
#   '06.03.2024',
#   ''],
#  ['CREEPYJAR (CRJ)',
#   'Kupuj',
#   '496,00 zł',
#   '760,00 zł',
#   '53,23%',
#   '580,00 zł',
#   'DM BDM',
#   '05.03.2024',
#   ''],
#  ['NOVAVISGR (NVG)*',
#   'Akumuluj',
#   '2,26 zł',
#   '3,12 zł',
#   '38,05%',
#   '2,63 zł',
#   'Erste',
#   '29.02.2024',
#   ''],
#  ['SYNEKTIK (SNT)',
#   'Kupuj',
#   '132,60 zł',
#   '138,10 zł',
#   '4,15%',
#   '117,50 zł',
#   'East Value Research',
#   '29.02.2024',
#   ''],
#  ['NOCTILUCA (NCL)',
#   'Wycena',
#   '92,00 zł',
#   '208,90 zł',
#   '127,07%',
#   '106,00 zł',
#   'East Value Research',
#   '23.02.2024',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 880,00 zł',
#   '19 282,00 zł',
#   '14,23%',
#   '17 130,00 zł',
#   'Noble Securities',
#   '21.02.2024',
#   ''],
#  ['XTB (XTB)',
#   'Kupuj',
#   '71,10 zł',
#   '47,95 zł',
#   '-32,56%',
#   '47,22 zł',
#   'BM mBank',
#   '20.02.2024',
#   ''],
#  ['CDPROJEKT (CDR)',
#   'Redukuj',
#   '143,80 zł',
#   '102,00 zł',
#   '-29,07%',
#   '114,50 zł',
#   'DM BDM',
#   '19.02.2024',
#   ''],
#  ['VIGOPHOTN (VGO)*',
#   'Kupuj',
#   '576,00 zł',
#   '600,00 zł',
#   '4,17%',
#   '484,00 zł',
#   'Ipopema Securities',
#   '19.02.2024',
#   ''],
#  ['ELQ (ELQ)',
#   'Kupuj',
#   '3,20 zł',
#   '4,80 zł',
#   '50,00%',
#   '2,40 zł',
#   'East Value Research',
#   '19.02.2024',
#   ''],
#  ['SKARBIEC (SKH)*',
#   'Kupuj',
#   '24,20 zł',
#   '33,00 zł',
#   '36,36%',
#   '23,60 zł',
#   'BM Banku Pekao',
#   '16.02.2024',
#   ''],
#  ['QUERCUS (QRS)*',
#   'Kupuj',
#   '6,20 zł',
#   '6,70 zł',
#   '8,06%',
#   '5,80 zł',
#   'BM Banku Pekao',
#   '16.02.2024',
#   ''],
#  ['PGE (PGE)',
#   'Sprzedaj',
#   '6,91 zł',
#   '7,20 zł',
#   '4,26%',
#   '8,42 zł',
#   'DM BOŚ',
#   '15.02.2024',
#   ''],
#  ['VOXEL (VOX)*',
#   'Kupuj',
#   '93,20 zł',
#   '97,70 zł',
#   '4,83%',
#   '88,60 zł',
#   'DM BOŚ',
#   '14.02.2024',
#   ''],
#  ['UNIMOT (UNT)',
#   'Kupuj',
#   '134,60 zł',
#   '160,00 zł',
#   '18,87%',
#   '131,60 zł',
#   'DM BOŚ',
#   '13.02.2024',
#   ''],
#  ['PKNORLEN (PKN)',
#   'Kupuj',
#   '67,68 zł',
#   '90,00 zł',
#   '32,98%',
#   '65,67 zł',
#   'DM BOŚ',
#   '09.02.2024',
#   ''],
#  ['MIRACULUM (MIR)*',
#   'Trzymaj',
#   '1,13 zł',
#   '1,35 zł',
#   '19,47%',
#   '1,36 zł',
#   'Ipopema Securities',
#   '09.02.2024',
#   ''],
#  ['NOVAVISGR (NVG)',
#   'Kupuj',
#   '2,26 zł',
#   '4,30 zł',
#   '90,27%',
#   '2,10 zł',
#   'East Value Research',
#   '08.02.2024',
#   ''],
#  ['FERRO (FRO)*',
#   'Kupuj',
#   '38,70 zł',
#   '36,60 zł',
#   '-5,43%',
#   '32,30 zł',
#   'DM BOŚ',
#   '07.02.2024',
#   ''],
#  ['RELPOL (RLP)*',
#   'Trzymaj',
#   '5,70 zł',
#   '7,42 zł',
#   '30,18%',
#   '7,08 zł',
#   'DM BDM',
#   '05.02.2024',
#   ''],
#  ['SECOGROUP (SWG)*',
#   'Kupuj',
#   '33,00 zł',
#   '36,20 zł',
#   '9,70%',
#   '31,20 zł',
#   'Erste',
#   '02.02.2024',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 880,00 zł',
#   '20 000,00 zł',
#   '18,48%',
#   '15 570,00 zł',
#   'BM mBank',
#   '01.02.2024',
#   ''],
#  ['11BIT (11B)',
#   'Kupuj',
#   '642,00 zł',
#   '808,00 zł',
#   '25,86%',
#   '572,00 zł',
#   'DM BDM',
#   '30.01.2024',
#   ''],
#  ['MOLECURE (MOC)',
#   'Kupuj',
#   '13,90 zł',
#   '34,00 zł',
#   '144,60%',
#   '18,70 zł',
#   'BM mBank',
#   '23.01.2024',
#   ''],
#  ['KRUK (KRU)',
#   'Kupuj',
#   '452,00 zł',
#   '532,36 zł',
#   '17,78%',
#   '457,20 zł',
#   'BM mBank',
#   '18.01.2024',
#   ''],
#  ['FORTE (FTE)',
#   'Akumuluj',
#   '21,90 zł',
#   '25,20 zł',
#   '15,07%',
#   '23,10 zł',
#   'Noble Securities',
#   '17.01.2024',
#   ''],
#  ['AGORA (AGO)*',
#   'Kupuj',
#   '11,26 zł',
#   '14,50 zł',
#   '28,77%',
#   '10,45 zł',
#   'DM BDM',
#   '09.01.2024',
#   ''],
#  ['WIRTUALNA (WPL)',
#   'Redukuj',
#   '106,40 zł',
#   '102,80 zł',
#   '-3,38%',
#   '118,00 zł',
#   'DM BDM',
#   '09.01.2024',
#   ''],
#  ['VIGOPHOTN (VGO)',
#   'Kupuj',
#   '576,00 zł',
#   '590,00 zł',
#   '2,43%',
#   '510,00 zł',
#   'East Value Research',
#   '08.01.2024',
#   ''],
#  ['PEKABEX (PBX)',
#   'Kupuj',
#   '26,80 zł',
#   '27,30 zł',
#   '1,87%',
#   '24,30 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['TORPOL (TOR)',
#   'Kupuj',
#   '36,30 zł',
#   '27,90 zł',
#   '-23,14%',
#   '24,90 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['MIRBUD (MRB)',
#   'Akumuluj',
#   '14,36 zł',
#   '9,09 zł',
#   '-36,70%',
#   '8,30 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['ERBUD (ERB)',
#   'Trzymaj',
#   '40,30 zł',
#   '41,10 zł',
#   '1,99%',
#   '41,30 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['INSTALKRK (INK)',
#   'Kupuj',
#   '47,90 zł',
#   '50,00 zł',
#   '4,38%',
#   '42,80 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['MOSTALZAB (MSZ)',
#   'Kupuj',
#   '4,23 zł',
#   '4,85 zł',
#   '14,66%',
#   '4,00 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['BUDIMEX (BDX)',
#   'Redukuj',
#   '695,50 zł',
#   '530,80 zł',
#   '-23,68%',
#   '636,00 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['ZUE (ZUE)*',
#   'Akumuluj',
#   '10,80 zł',
#   '8,43 zł',
#   '-21,94%',
#   '7,86 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['ELEKTROTI (ELT)*',
#   'Akumuluj',
#   '34,80 zł',
#   '19,10 zł',
#   '-45,11%',
#   '17,48 zł',
#   'DM BDM',
#   '04.01.2024',
#   ''],
#  ['VOXEL (VOX)',
#   'Kupuj',
#   '93,20 zł',
#   '90,30 zł',
#   '-3,11%',
#   '78,60 zł',
#   'DM BDM',
#   '02.01.2024',
#   ''],
#  ['OPONEO.PL (OPN)',
#   'Kupuj',
#   '76,20 zł',
#   '63,80 zł',
#   '-16,27%',
#   '46,50 zł',
#   'East Value Research',
#   '27.12.2023',
#   ''],
#  ['HUUUGE (HUG)',
#   'Kupuj',
#   '23,30 zł',
#   '36,20 zł',
#   '55,36%',
#   '26,90 zł',
#   'DM BDM',
#   '22.12.2023',
#   ''],
#  ['GRODNO (GRN)*',
#   'Trzymaj',
#   '10,50 zł',
#   '11,80 zł',
#   '12,38%',
#   '10,94 zł',
#   'DM BOŚ',
#   '19.12.2023',
#   ''],
#  ['AMICA (AMC)',
#   'Kupuj',
#   '69,70 zł',
#   '109,20 zł',
#   '56,67%',
#   '82,00 zł',
#   'Noble Securities',
#   '15.12.2023',
#   ''],
#  ['SYNEKTIK (SNT)',
#   'Kupuj',
#   '132,60 zł',
#   '109,70 zł',
#   '-17,27%',
#   '89,20 zł',
#   'East Value Research',
#   '14.12.2023',
#   ''],
#  ['MARVIPOL (MVP)*',
#   'Kupuj',
#   '7,16 zł',
#   '10,07 zł',
#   '40,64%',
#   '7,20 zł',
#   'Ipopema Securities',
#   '12.12.2023',
#   ''],
#  ['KINOPOL (KPL)*',
#   'Wycena',
#   '17,70 zł',
#   '18,40 zł',
#   '3,95%',
#   '14,65 zł',
#   'DM BDM',
#   '11.12.2023',
#   ''],
#  ['BRAND24 (B24)*',
#   'Wycena',
#   '46,90 zł',
#   '48,80 zł',
#   '4,05%',
#   '36,30 zł',
#   'DM BOŚ',
#   '11.12.2023',
#   ''],
#  ['VOXEL (VOX)*',
#   'Kupuj',
#   '93,20 zł',
#   '85,30 zł',
#   '-8,48%',
#   '74,20 zł',
#   'DM BOŚ',
#   '11.12.2023',
#   ''],
#  ['CLOUD (CLD)*',
#   'Trzymaj',
#   '76,00 zł',
#   '71,00 zł',
#   '-6,58%',
#   '68,00 zł',
#   'DM BOŚ',
#   '11.12.2023',
#   ''],
#  ['VOTUM (VOT)*',
#   'Kupuj',
#   '33,60 zł',
#   '81,30 zł',
#   '141,96%',
#   '43,70 zł',
#   'DM BOŚ',
#   '11.12.2023',
#   ''],
#  ['DATAWALK (DAT)*',
#   'Trzymaj',
#   '65,10 zł',
#   '53,00 zł',
#   '-18,59%',
#   '32,50 zł',
#   'DM BOŚ',
#   '11.12.2023',
#   ''],
#  ['FERRO (FRO)*',
#   'Kupuj',
#   '38,70 zł',
#   '34,70 zł',
#   '-10,34%',
#   '31,60 zł',
#   'DM BOŚ',
#   '11.12.2023',
#   ''],
#  ['KINOPOL (KPL)*',
#   'Kupuj',
#   '17,70 zł',
#   '18,40 zł',
#   '3,95%',
#   '14,00 zł',
#   'DM BDM',
#   '11.12.2023',
#   ''],
#  ['MCI (MCI)*',
#   'Wycena',
#   '26,50 zł',
#   '40,30 zł',
#   '52,08%',
#   '23,70 zł',
#   'Noble Securities',
#   '08.12.2023',
#   ''],
#  ['KOGENERA (KGN)',
#   'Wycena',
#   '46,70 zł',
#   '137,00 zł',
#   '193,36%',
#   '42,00 zł',
#   'East Value Research',
#   '08.12.2023',
#   ''],
#  ['BOWIM (BOW)*',
#   'Wycena',
#   '6,70 zł',
#   '7,20 zł',
#   '7,46%',
#   '7,20 zł',
#   'DM BOŚ',
#   '08.12.2023',
#   ''],
#  ['AILLERON (ALL)',
#   'Wycena',
#   '17,40 zł',
#   '22,70 zł',
#   '30,46%',
#   '19,20 zł',
#   'Noble Securities',
#   '07.12.2023',
#   ''],
#  ['CLNPHARMA (CLN)',
#   'Kupuj',
#   '15,64 zł',
#   '29,10 zł',
#   '86,06%',
#   '15,66 zł',
#   'Noble Securities',
#   '06.12.2023',
#   ''],
#  ['SONEL (SON)*',
#   'Wycena',
#   '18,00 zł',
#   '12,36 zł',
#   '-31,33%',
#   '11,70 zł',
#   'Noble Securities',
#   '05.12.2023',
#   ''],
#  ['CAPTORTX (CTX)',
#   'Kupuj',
#   '78,60 zł',
#   '137,10 zł',
#   '74,43%',
#   '86,60 zł',
#   'Noble Securities',
#   '04.12.2023',
#   ''],
#  ['PEKAO (PEO)',
#   'Kupuj',
#   '164,75 zł',
#   '201,80 zł',
#   '22,49%',
#   '147,80 zł',
#   'DM BOŚ',
#   '04.12.2023',
#   ''],
#  ['PKOBP (PKO)',
#   'Kupuj',
#   '62,52 zł',
#   '64,40 zł',
#   '3,01%',
#   '49,55 zł',
#   'DM BOŚ',
#   '04.12.2023',
#   ''],
#  ['MILLENNIUM (MIL)',
#   'Kupuj',
#   '8,91 zł',
#   '11,30 zł',
#   '26,90%',
#   '8,11 zł',
#   'DM BOŚ',
#   '04.12.2023',
#   ''],
#  ['WARIMPEX (WXF)',
#   'Wycena',
#   '3,69 zł',
#   '11,68 zł',
#   '216,53%',
#   '3,48 zł',
#   'East Value Research',
#   '04.12.2023',
#   ''],
#  ['ALLEGRO (ALE)',
#   'Kupuj',
#   '37,60 zł',
#   '35,30 zł',
#   '-6,10%',
#   '28,94 zł',
#   'BM mBank',
#   '01.12.2023',
#   ''],
#  ['ARTIFEX (ART)*',
#   'Kupuj',
#   '22,80 zł',
#   '24,80 zł',
#   '8,77%',
#   '16,95 zł',
#   'DM BDM',
#   '01.12.2023',
#   ''],
#  ['IFIRMA (IFI)*',
#   'Neutralna',
#   '23,40 zł',
#   '30,90 zł',
#   '32,05%',
#   '29,80 zł',
#   'Millennium DM',
#   '30.11.2023',
#   ''],
#  ['MOSTALZAB (MSZ)*',
#   'Kupuj',
#   '4,23 zł',
#   '5,80 zł',
#   '37,12%',
#   '3,87 zł',
#   'Millennium DM',
#   '30.11.2023',
#   ''],
#  ['TSGAMES (TEN)',
#   'Kupuj',
#   '84,55 zł',
#   '138,00 zł',
#   '63,22%',
#   '90,35 zł',
#   'DM BDM',
#   '30.11.2023',
#   ''],
#  ['FERRO (FRO)*',
#   'Kupuj',
#   '38,70 zł',
#   '33,30 zł',
#   '-13,95%',
#   '26,60 zł',
#   'DM BOŚ',
#   '29.11.2023',
#   ''],
#  ['XTB (XTB)',
#   'Kupuj',
#   '71,10 zł',
#   '67,70 zł',
#   '-4,78%',
#   '34,10 zł',
#   'Noble Securities',
#   '28.11.2023',
#   ''],
#  ['MOBRUK (MBR)',
#   'Kupuj',
#   '317,00 zł',
#   '390,30 zł',
#   '23,12%',
#   '280,00 zł',
#   'Noble Securities',
#   '28.11.2023',
#   ''],
#  ['SELVITA (SLV)',
#   'Akumuluj',
#   '67,30 zł',
#   '72,60 zł',
#   '7,88%',
#   '60,00 zł',
#   'Noble Securities',
#   '28.11.2023',
#   ''],
#  ['DECORA (DCR)',
#   'Kupuj',
#   '63,80 zł',
#   '60,40 zł',
#   '-5,33%',
#   '54,20 zł',
#   'DM BOŚ',
#   '28.11.2023',
#   ''],
#  ['ALIOR (ALR)',
#   'Kupuj',
#   '99,90 zł',
#   '93,30 zł',
#   '-6,61%',
#   '74,36 zł',
#   'DM BOŚ',
#   '27.11.2023',
#   ''],
#  ['SHOPER (SHO)',
#   'Kupuj',
#   '43,20 zł',
#   '36,50 zł',
#   '-15,51%',
#   '33,50 zł',
#   'BM mBank',
#   '23.11.2023',
#   ''],
#  ['PEPCO (PCO)',
#   'Trzymaj',
#   '22,25 zł',
#   '19,00 zł',
#   '-14,61%',
#   '19,37 zł',
#   'Noble Securities',
#   '20.11.2023',
#   ''],
#  ['GRUPRACUJ (GPP)',
#   'Trzymaj',
#   '63,70 zł',
#   '63,40 zł',
#   '-0,47%',
#   '61,00 zł',
#   'BM Banku Pekao',
#   '20.11.2023',
#   ''],
#  ['PKOBP (PKO)',
#   'Kupuj',
#   '62,52 zł',
#   '55,21 zł',
#   '-11,69%',
#   '47,68 zł',
#   'BM mBank',
#   '17.11.2023',
#   ''],
#  ['GRUPAAZOTY (ATT)',
#   'Sprzedaj',
#   '20,88 zł',
#   '17,26 zł',
#   '-17,34%',
#   '21,30 zł',
#   'BM Banku Pekao',
#   '17.11.2023',
#   ''],
#  ['PCCROKITA (PCR)',
#   'Sprzedaj',
#   '91,70 zł',
#   '79,04 zł',
#   '-13,81%',
#   '91,00 zł',
#   'BM Banku Pekao',
#   '17.11.2023',
#   ''],
#  ['SCPFL (SCP)*',
#   'Kupuj',
#   '167,00 zł',
#   '230,20 zł',
#   '37,84%',
#   '165,00 zł',
#   'Ipopema Securities',
#   '16.11.2023',
#   ''],
#  ['MEDICALG (MDG)*',
#   'Kupuj',
#   '27,40 zł',
#   '41,20 zł',
#   '50,36%',
#   '26,25 zł',
#   'Ipopema Securities',
#   '16.11.2023',
#   ''],
#  ['PEPCO (PCO)',
#   'Kupuj',
#   '22,25 zł',
#   '32,70 zł',
#   '46,97%',
#   '19,00 zł',
#   'BM mBank',
#   '15.11.2023',
#   ''],
#  ['RYVU (RVU)',
#   'Kupuj',
#   '50,90 zł',
#   '77,70 zł',
#   '52,65%',
#   '56,90 zł',
#   'Noble Securities',
#   '15.11.2023',
#   ''],
#  ['SANOK (SNK)',
#   'Trzymaj',
#   '20,10 zł',
#   '24,80 zł',
#   '23,38%',
#   '23,10 zł',
#   'DM BOŚ',
#   '10.11.2023',
#   ''],
#  ['RYVU (RVU)',
#   'Trzymaj',
#   '50,90 zł',
#   '65,00 zł',
#   '27,70%',
#   '56,70 zł',
#   'BM mBank',
#   '07.11.2023',
#   ''],
#  ['ORANGEPL (OPL)',
#   'Kupuj',
#   '7,65 zł',
#   '9,60 zł',
#   '25,42%',
#   '8,02 zł',
#   'BM mBank',
#   '07.11.2023',
#   ''],
#  ['SELVITA (SLV)',
#   'Trzymaj',
#   '67,30 zł',
#   '74,20 zł',
#   '10,25%',
#   '59,50 zł',
#   'DM BOŚ',
#   '07.11.2023',
#   ''],
#  ['BOOMBIT (BBT)',
#   'Kupuj',
#   '10,55 zł',
#   '18,90 zł',
#   '79,15%',
#   '10,85 zł',
#   'DM BDM',
#   '06.11.2023',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 880,00 zł',
#   '18 105,00 zł',
#   '7,26%',
#   '13 900,00 zł',
#   'DM BOŚ',
#   '06.11.2023',
#   ''],
#  ['DATAWALK (DAT)*',
#   'Trzymaj',
#   '65,10 zł',
#   '53,00 zł',
#   '-18,59%',
#   '50,50 zł',
#   'DM BOŚ',
#   '03.11.2023',
#   ''],
#  ['VOXEL (VOX)*',
#   'Kupuj',
#   '93,20 zł',
#   '75,80 zł',
#   '-18,67%',
#   '59,60 zł',
#   'DM BOŚ',
#   '02.11.2023',
#   ''],
#  ['SANPL (SPL)',
#   'Kupuj',
#   '534,00 zł',
#   '486,63 zł',
#   '-8,87%',
#   '456,40 zł',
#   'BM mBank',
#   '02.11.2023',
#   ''],
#  ['ASSECOSEE (ASE)',
#   'Kupuj',
#   '51,00 zł',
#   '50,00 zł',
#   '-1,96%',
#   '46,00 zł',
#   'DM BOŚ',
#   '02.11.2023',
#   ''],
#  ['ACTION (ACT)*',
#   'Kupuj',
#   '20,80 zł',
#   '21,60 zł',
#   '3,85%',
#   '18,40 zł',
#   'DM BOŚ',
#   '02.11.2023',
#   ''],
#  ['UNIMOT (UNT)',
#   'Trzymaj',
#   '134,60 zł',
#   '105,00 zł',
#   '-21,99%',
#   '100,40 zł',
#   'DM BOŚ',
#   '31.10.2023',
#   ''],
#  ['PEKABEX (PBX)',
#   'Kupuj',
#   '26,80 zł',
#   '24,00 zł',
#   '-10,45%',
#   '21,30 zł',
#   'Trigon DM',
#   '30.10.2023',
#   ''],
#  ['VOXEL (VOX)*',
#   'Kupuj',
#   '93,20 zł',
#   '73,90 zł',
#   '-20,71%',
#   '53,00 zł',
#   'DM BOŚ',
#   '30.10.2023',
#   ''],
#  ['FERRO (FRO)*',
#   'Neutralna',
#   '38,70 zł',
#   '30,10 zł',
#   '-22,22%',
#   '27,20 zł',
#   'DM BOŚ',
#   '25.10.2023',
#   ''],
#  ['LPP (LPP)',
#   'Kupuj',
#   '16 880,00 zł',
#   '16 795,00 zł',
#   '-0,50%',
#   '12 670,00 zł',
#   'Noble Securities',
#   '25.10.2023',
#   ''],
#  ['DADELO (DAD)*',
#   'Kupuj',
#   '19,70 zł',
#   '18,50 zł',
#   '-6,09%',
#   '16,30 zł',
#   'Trigon DM',
#   '24.10.2023',
#   ''],
#  ['AILLERON (ALL)',
#   'Kupuj',
#   '17,40 zł',
#   '28,00 zł',
#   '60,92%',
#   '19,00 zł',
#   'Trigon DM',
#   '23.10.2023',
#   ''],
#  ['SELENAFM (SEL)',
#   'Kupuj',
#   '36,10 zł',
#   '42,50 zł',
#   '17,73%',
#   '29,90 zł',
#   'Trigon DM',
#   '23.10.2023',
#   ''],
#  ['MFO (MFO)*',
#   'Kupuj',
#   '32,10 zł',
#   '42,60 zł',
#   '32,71%',
#   '29,30 zł',
#   'Trigon DM',
#   '23.10.2023',
#   ''],
#  ['KOGENERA (KGN)',
#   'Wycena',
#   '46,70 zł',
#   '150,30 zł',
#   '221,84%',
#   '39,70 zł',
#   'East Value Research',
#   '23.10.2023',
#   ''],
#  ['MANGATA (MGT)',
#   'Kupuj',
#   '95,00 zł',
#   '110,40 zł',
#   '16,21%',
#   '94,00 zł',
#   'DM BOŚ',
#   '20.10.2023',
#   ''],
#  ['ASSECOPOL (ACP)',
#   'Trzymaj',
#   '79,00 zł',
#   '84,30 zł',
#   '6,71%',
#   '76,05 zł',
#   'DM BOŚ',
#   '20.10.2023',
#   ''],
#  ['PCCROKITA (PCR)',
#   'Trzymaj',
#   '91,70 zł',
#   '100,00 zł',
#   '9,05%',
#   '98,80 zł',
#   'DM BOŚ',
#   '18.10.2023',
#   ''],
#  ['KRUK (KRU)',
#   'Kupuj',
#   '452,00 zł',
#   '493,25 zł',
#   '9,13%',
#   '461,40 zł',
#   'BM mBank',
#   '17.10.2023',
#   ''],
#  ['KETY (KTY)',
#   'Trzymaj',
#   '891,50 zł',
#   '696,20 zł',
#   '-21,91%',
#   '638,00 zł',
#   'BM mBank',
#   '13.10.2023',
#   ''],
#  ['SUNEX (SNX)',
#   'Trzymaj',
#   '10,40 zł',
#   '12,00 zł',
#   '15,38%',
#   '13,06 zł',
#   'Ipopema Securities',
#   '13.10.2023',
#   ''],
#  ['JSW (JSW)',
#   'Kupuj',
#   '29,60 zł',
#   '65,00 zł',
#   '119,59%',
#   '43,70 zł',
#   'DM BOŚ',
#   '13.10.2023',
#   ''],
#  ['ATAL (1AT)',
#   'Kupuj',
#   '60,60 zł',
#   '72,82 zł',
#   '20,17%',
#   '62,20 zł',
#   'BM mBank',
#   '10.10.2023',
#   ''],
#  ['ELEKTROTI (ELT)*',
#   'Kupuj',
#   '34,80 zł',
#   '17,10 zł',
#   '-50,86%',
#   '14,42 zł',
#   'DM BDM',
#   '10.10.2023',
#   ''],
#  ['AUTOPARTN (APR)',
#   'Kupuj',
#   '24,10 zł',
#   '33,90 zł',
#   '40,66%',
#   '23,00 zł',
#   'Noble Securities',
#   '09.10.2023',
#   ''],
#  ['INTERCARS (CAR)',
#   'Kupuj',
#   '547,00 zł',
#   '708,00 zł',
#   '29,43%',
#   '560,00 zł',
#   'Noble Securities',
#   '09.10.2023',
#   ''],
#  ['WITTCHEN (WTN)',
#   'Kupuj',
#   '32,05 zł',
#   '30,40 zł',
#   '-5,15%',
#   '23,80 zł',
#   'DM Banku BPS',
#   '06.10.2023',
#   ''],
#  ['4MASS (4MS)',
#   'Kupuj',
#   '5,84 zł',
#   '13,20 zł',
#   '126,03%',
#   '5,99 zł',
#   'East Value Research',
#   '05.10.2023',
#   ''],
#  ['DEVELIA (DVL)',
#   'Kupuj',
#   '5,60 zł',
#   '5,62 zł',
#   '0,36%',
#   '4,88 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['DOMDEV (DOM)',
#   'Trzymaj',
#   '176,60 zł',
#   '153,52 zł',
#   '-13,07%',
#   '153,80 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['ALIOR (ALR)',
#   'Kupuj',
#   '99,90 zł',
#   '65,00 zł',
#   '-34,93%',
#   '52,50 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['PKOBP (PKO)',
#   'Kupuj',
#   '62,52 zł',
#   '44,90 zł',
#   '-28,18%',
#   '34,57 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['INGBSK (ING)',
#   'Kupuj',
#   '300,00 zł',
#   '209,00 zł',
#   '-30,33%',
#   '179,40 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['BOS (BOS)',
#   'Kupuj',
#   '14,60 zł',
#   '11,36 zł',
#   '-22,19%',
#   '8,44 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['MILLENNIUM (MIL)',
#   'Kupuj',
#   '8,91 zł',
#   '7,15 zł',
#   '-19,71%',
#   '5,85 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['BNPPPL (BNP)',
#   'Kupuj',
#   '100,50 zł',
#   '71,58 zł',
#   '-28,78%',
#   '56,60 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['SANPL (SPL)',
#   'Kupuj',
#   '534,00 zł',
#   '413,63 zł',
#   '-22,54%',
#   '360,60 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['PEKAO (PEO)',
#   'Kupuj',
#   '164,75 zł',
#   '141,97 zł',
#   '-13,83%',
#   '101,00 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['AMBRA (AMB)*',
#   'Kupuj',
#   '27,20 zł',
#   '35,90 zł',
#   '31,99%',
#   '29,30 zł',
#   'Millennium DM',
#   '04.10.2023',
#   ''],
#  ['HANDLOWY (BHW)',
#   'Kupuj',
#   '109,00 zł',
#   '99,00 zł',
#   '-9,17%',
#   '79,70 zł',
#   'BM mBank',
#   '04.10.2023',
#   ''],
#  ['BRAND24 (B24)*',
#   'Wycena',
#   '46,90 zł',
#   '48,80 zł',
#   '4,05%',
#   '36,00 zł',
#   'DM BOŚ',
#   '04.10.2023',
#   ''],
#  ['VOTUM (VOT)*',
#   'Kupuj',
#   '33,60 zł',
#   '79,50 zł',
#   '136,61%',
#   '43,10 zł',
#   'DM BOŚ',
#   '04.10.2023',
#   ''],
#  ['BENEFIT (BFT)',
#   'Kupuj',
#   '2 900,00 zł',
#   '2 100,00 zł',
#   '-27,59%',
#   '1 730,00 zł',
#   'DM BOŚ',
#   '03.10.2023',
#   ''],
#  ['MABION (MAB)',
#   'Wycena',
#   '16,98 zł',
#   '23,60 zł',
#   '38,99%',
#   '16,99 zł',
#   'Noble Securities',
#   '02.10.2023',
#   ''],
#  ['MLSYSTEM (MLS)*',
#   'Kupuj',
#   '40,40 zł',
#   '87,20 zł',
#   '115,84%',
#   '65,30 zł',
#   'Ipopema Securities',
#   '02.10.2023',
#   ''],
#  ['RELPOL (RLP)*',
#   'Trzymaj',
#   '5,70 zł',
#   '8,62 zł',
#   '51,23%',
#   '8,46 zł',
#   'DM BDM',
#   '26.09.2023',
#   ''],
#  ['RAEN (RAE)',
#   'Wycena',
#   '0,61 zł',
#   '1,90 zł',
#   '211,48%',
#   '0,51 zł',
#   'East Value Research',
#   '26.09.2023',
#   ''],
#  ['EUROCASH (EUR)',
#   'Trzymaj',
#   '13,20 zł',
#   '15,00 zł',
#   '13,64%',
#   '15,20 zł',
#   'Noble Securities',
#   '22.09.2023',
#   ''],
#  ['DINOPL (DNP)',
#   'Akumuluj',
#   '416,10 zł',
#   '431,80 zł',
#   '3,77%',
#   '373,10 zł',
#   'Noble Securities',
#   '22.09.2023',
#   ''],
#  ['MIRACULUM (MIR)',
#   'Trzymaj',
#   '1,13 zł',
#   '1,25 zł',
#   '10,62%',
#   '1,33 zł',
#   'Ipopema Securities',
#   '22.09.2023',
#   ''],
#  ['TORPOL (TOR)',
#   'Trzymaj',
#   '36,30 zł',
#   '19,30 zł',
#   '-46,83%',
#   '18,66 zł',
#   'DM BDM',
#   '20.09.2023',
#   ''],
#  ['BIOTON (BIO)*',
#   'Wycena',
#   '3,47 zł',
#   '5,41 zł',
#   '55,91%',
#   '3,83 zł',
#   'Noble Securities',
#   '19.09.2023',
#   ''],
#  ['UNIBEP (UNI)',
#   'Wycena',
#   '9,38 zł',
#   '12,50 zł',
#   '33,26%',
#   '10,40 zł',
#   'Noble Securities',
#   '15.09.2023',
#   ''],
#  ['BIOMAXIMA (BMX)',
#   'Kupuj',
#   '15,45 zł',
#   '26,40 zł',
#   '70,87%',
#   '19,20 zł',
#   'DM BDM',
#   '15.09.2023',
#   ''],
#  ['SYGNITY (SGN)*',
#   'Sprzedaj',
#   '62,40 zł',
#   '21,60 zł',
#   '-65,38%',
#   '32,80 zł',
#   'BM mBank',
#   '15.09.2023',
#   ''],
#  ['SELENAFM (SEL)',
#   'Kupuj',
#   '36,10 zł',
#   '40,40 zł',
#   '11,91%',
#   '25,40 zł',
#   'Trigon DM',
#   '14.09.2023',
#   ''],
#  ['ATMGRUPA (ATG)',
#   'Kupuj',
#   '4,46 zł',
#   '4,51 zł',
#   '1,12%',
#   '3,29 zł',
#   'DM BDM',
#   '14.09.2023',
#   ''],
#  ['AGORA (AGO)',
#   'Kupuj',
#   '11,26 zł',
#   '10,46 zł',
#   '-7,10%',
#   '7,84 zł',
#   'DM BDM',
#   '13.09.2023',
#   ''],
#  ['ZUE (ZUE)',
#   'Kupuj',
#   '10,80 zł',
#   '7,76 zł',
#   '-28,15%',
#   '5,62 zł',
#   'DM BDM',
#   '12.09.2023',
#   ''],
#  ['CLOUD (CLD)',
#   'Wycena',
#   '76,00 zł',
#   '88,00 zł',
#   '15,79%',
#   '94,00 zł',
#   'DM BOŚ',
#   '11.09.2023',
#   ''],
#  ['SCPFL (SCP)*',
#   'Kupuj',
#   '167,00 zł',
#   '235,80 zł',
#   '41,20%',
#   '165,00 zł',
#   'Ipopema Securities',
#   '11.09.2023',
#   ''],
#  ['CYBERFLKS (CBF)',
#   'Kupuj',
#   '125,00 zł',
#   '95,00 zł',
#   '-24,00%',
#   '81,00 zł',
#   'BM mBank',
#   '11.09.2023',
#   ''],
#  ['VERCOM (VRC)',
#   'Trzymaj',
#   '135,50 zł',
#   '67,40 zł',
#   '-50,26%',
#   '69,40 zł',
#   'BM mBank',
#   '11.09.2023',
#   ''],
#  ['PGE (PGE)',
#   'Kupuj',
#   '6,91 zł',
#   '11,00 zł',
#   '59,28%',
#   '7,57 zł',
#   'DM BOŚ',
#   '11.09.2023',
#   ''],
#  ['BOWIM (BOW)',
#   'Wycena',
#   '6,70 zł',
#   '6,90 zł',
#   '2,99%',
#   '7,05 zł',
#   'DM BOŚ',
#   '11.09.2023',
#   ''],
#  ['ZEPAK (ZEP)',
#   'Trzymaj',
#   '18,90 zł',
#   '20,60 zł',
#   '8,99%',
#   '20,20 zł',
#   'BM Banku Pekao',
#   '11.09.2023',
#   ''],
#  ['ATENDE (ATD)',
#   'Kupuj',
#   '3,00 zł',
#   '4,80 zł',
#   '60,00%',
#   '2,90 zł',
#   'BM Banku Pekao',
#   '11.09.2023',
#   ''],
#  ['SECOGROUP (SWG)*',
#   'Kupuj',
#   '33,00 zł',
#   '33,33 zł',
#   '1,00%',
#   '26,00 zł',
#   'Erste',
#   '08.09.2023',
#   ''],
#  ['IFIRMA (IFI)',
#   'Akumuluj',
#   '23,40 zł',
#   '36,60 zł',
#   '56,41%',
#   '33,30 zł',
#   'Millennium DM',
#   '08.09.2023',
#   ''],
#  ['SKARBIEC (SKH)',
#   'Kupuj',
#   '24,20 zł',
#   '32,00 zł',
#   '32,23%',
#   '20,40 zł',
#   'BM Banku Pekao',
#   '08.09.2023',
#   ''],
#  ['QUERCUS (QRS)',
#   'Kupuj',
#   '6,20 zł',
#   '5,30 zł',
#   '-14,52%',
#   '4,03 zł',
#   'BM Banku Pekao',
#   '08.09.2023',
#   ''],
#  ['STALPROFI (STF)',
#   'Sprzedaj',
#   '9,32 zł',
#   '8,00 zł',
#   '-14,16%',
#   '8,64 zł',
#   'BM Banku Pekao',
#   '08.09.2023',
#   ''],
#  ['IMS (IMS)',
#   'Kupuj',
#   '4,38 zł',
#   '3,80 zł',
#   '-13,24%',
#   '2,80 zł',
#   'Millennium DM',
#   '08.09.2023',
#   ''],
#  ['MABION (MAB)',
#   'Wycena',
#   '16,98 zł',
#   '22,90 zł',
#   '34,86%',
#   '17,96 zł',
#   'Noble Securities',
#   '08.09.2023',
#   ''],
#  ['MLPGROUP (MLG)*',
#   'Kupuj',
#   '83,00 zł',
#   '115,00 zł',
#   '38,55%',
#   '78,20 zł',
#   'BM PKO BP',
#   '08.09.2023',
#   ''],
#  ['MARVIPOL (MVP)',
#   'Kupuj',
#   '7,16 zł',
#   '10,49 zł',
#   '46,51%',
#   '8,00 zł',
#   'Ipopema Securities',
#   '07.09.2023',
#   ''],
#  ['MERCOR (MCR)',
#   'Kupuj',
#   '24,80 zł',
#   '37,00 zł',
#   '49,19%',
#   '25,20 zł',
#   'BM Banku Pekao',
#   '06.09.2023',
#   ''],
#  ['WARIMPEX (WXF)',
#   'Wycena',
#   '3,69 zł',
#   '8,99 zł',
#   '143,63%',
#   '4,90 zł',
#   'East Value Research',
#   '05.09.2023',
#   ''],
#  ['SYNEKTIK (SNT)',
#   'Kupuj',
#   '132,60 zł',
#   '87,00 zł',
#   '-34,39%',
#   '72,60 zł',
#   'BM mBank',
#   '05.09.2023',
#   ''],
#  ['NEWAG (NWG)',
#   'Przeważaj',
#   '31,10 zł',
#   '25,00 zł',
#   '-19,61%',
#   '18,20 zł',
#   'Santander BM',
#   '05.09.2023',
#   ''],
#  ['WARIMPEX (WXF)',
#   '',
#   '3,69 zł',
#   '2,11 zł',
#   '-42,82%',
#   '4,78 zł',
#   'East Value Research',
#   '05.09.2023',
#   ''],
#  ['PEPCO (PCO)',
#   'Kupuj',
#   '22,25 zł',
#   '42,10 zł',
#   '89,21%',
#   '32,70 zł',
#   'Noble Securities',
#   '04.09.2023',
#   ''],
#  ['VINDEXUS (VIN)',
#   'Kupuj',
#   '9,60 zł',
#   '13,90 zł',
#   '44,79%',
#   '8,10 zł',
#   'East Value Research',
#   '04.09.2023',
#   ''],
#  ['XTPL (XTP)',
#   'Kupuj',
#   '125,40 zł',
#   '216,00 zł',
#   '72,25%',
#   '165,00 zł',
#   'Erste',
#   '31.08.2023',
#   ''],
#  ['SYNEKTIK (SNT)',
#   'Kupuj',
#   '132,60 zł',
#   '95,50 zł',
#   '-27,98%',
#   '67,60 zł',
#   'East Value Research',
#   '31.08.2023',
#   ''],
#  ['ARTIFEX (ART)',
#   'Kupuj',
#   '22,80 zł',
#   '22,80 zł',
#   '0,00%',
#   '17,60 zł',
#   'DM BDM',
#   '30.08.2023',
#   ''],
#  ['AILLERON (ALL)',
#   'Kupuj',
#   '17,40 zł',
#   '26,00 zł',
#   '49,43%',
#   '18,40 zł',
#   'Trigon DM',
#   '30.08.2023',
#   ''],
#  ['ENTER (ENT)*',
#   'Kupuj',
#   '67,20 zł',
#   '59,80 zł',
#   '-11,01%',
#   '43,50 zł',
#   'DM BDM',
#   '29.08.2023',
#   ''],
#  ['SYNEKTIK (SNT)',
#   'Kupuj',
#   '132,60 zł',
#   '87,00 zł',
#   '-34,39%',
#   '68,60 zł',
#   'BM mBank',
#   '28.08.2023',
#   ''],
#  ['WIRTUALNA (WPL)',
#   'Akumuluj',
#   '106,40 zł',
#   '129,10 zł',
#   '21,33%',
#   '114,20 zł',
#   'DM BDM',
#   '28.08.2023',
#   ''],
#  ['ASBIS (ASB)',
#   'Wycena',
#   '24,24 zł',
#   '67,00 zł',
#   '176,40%',
#   '28,74 zł',
#   'Argus Research',
#   '25.08.2023',
#   ''],
#  ['OPONEO.PL (OPN)*',
#   'Kupuj',
#   '76,20 zł',
#   '51,00 zł',
#   '-33,07%',
#   '43,00 zł',
#   'BM PKO BP',
#   '23.08.2023',
#   ''],
#  ['ORANGEPL (OPL)',
#   'Kupuj',
#   '7,65 zł',
#   '8,87 zł',
#   '15,89%',
#   '6,83 zł',
#   'DM BDM',
#   '21.08.2023',
#   ''],
#  ['NEUCA (NEU)',
#   'Kupuj',
#   '927,00 zł',
#   '855,00 zł',
#   '-7,77%',
#   '750,00 zł',
#   'DM BOŚ',
#   '17.08.2023',
#   ''],
#  ['INTERCARS (CAR)',
#   'Trzymaj',
#   '547,00 zł',
#   '595,00 zł',
#   '8,78%',
#   '589,00 zł',
#   'DM BOŚ',
#   '16.08.2023',
#   ''],
#  ['BOGDANKA (LWB)',
#   'Sprzedaj',
#   '29,94 zł',
#   '33,00 zł',
#   '10,22%',
#   '35,52 zł',
#   'DM BOŚ',
#   '16.08.2023',
#   ''],
#  ['SECOGROUP (SWG)',
#   'Kupuj',
#   '33,00 zł',
#   '33,32 zł',
#   '0,97%',
#   '27,80 zł',
#   'Erste',
#   '16.08.2023',
#   ''],
#  ['ABPL (ABE)',
#   'Kupuj',
#   '104,00 zł',
#   '82,60 zł',
#   '-20,58%',
#   '59,60 zł',
#   'DM BOŚ',
#   '11.08.2023',
#   ''],
#  ['BOGDANKA (LWB)',
#   'Akumuluj',
#   '29,94 zł',
#   '42,28 zł',
#   '41,22%',
#   '36,20 zł',
#   'Noble Securities',
#   '04.08.2023',
#   ''],
#  ['SNIEZKA (SKA)',
#   'Akumuluj',
#   '89,40 zł',
#   '79,90 zł',
#   '-10,63%',
#   '72,80 zł',
#   'DM BDM',
#   '04.08.2023',
#   ''],
#  ['VOXEL (VOX)*',
#   'Kupuj',
#   '93,20 zł',
#   '66,30 zł',
#   '-28,86%',
#   '53,60 zł',
#   'DM BOŚ',
#   '03.08.2023',
#   ''],
#  ['FERRO (FRO)*',
#   'Trzymaj',
#   '38,70 zł',
#   '30,10 zł',
#   '-22,22%',
#   '30,00 zł',
#   'DM BOŚ',
#   '01.08.2023',
#   ''],
#  ['ARCHICOM (ARH)',
#   'Kupuj',
#   '36,00 zł',
#   '35,00 zł',
#   '-2,78%',
#   '26,10 zł',
#   'Trigon DM',
#   '31.07.2023',
#   ''],
#  ['CDPROJEKT (CDR)',
#   'Trzymaj',
#   '143,80 zł',
#   '152,00 zł',
#   '5,70%',
#   '164,40 zł',
#   'DM BOŚ',
#   '31.07.2023',
#   ''],
#  ['CCC (CCC)',
#   'Kupuj',
#   '123,00 zł',
#   '63,90 zł',
#   '-48,05%',
#   '49,30 zł',
#   'BM mBank',
#   '27.07.2023',
#   ''],
#  ['CYFRPLSAT (CPS)',
#   'Trzymaj',
#   '12,18 zł',
#   '16,70 zł',
#   '37,11%',
#   '16,20 zł',
#   'DM BOŚ',
#   '26.07.2023',
#   ''],
#  ['STSHOLDING (STH)',
#   'Sprzedaj',
#   '24,60 zł',
#   '24,80 zł',
#   '0,81%',
#   '24,60 zł',
#   'DM BOŚ',
#   '25.07.2023',
#   ''],
#  ['BUDIMEX (BDX)',
#   'Redukuj',
#   '695,50 zł',
#   '376,50 zł',
#   '-45,87%',
#   '443,50 zł',
#   'DM BDM',
#   '25.07.2023',
#   ''],
#  ['RAINBOW (RBW)',
#   'Kupuj',
#   '113,00 zł',
#   '65,00 zł',
#   '-42,48%',
#   '42,90 zł',
#   'Trigon DM',
#   '25.07.2023',
#   ''],
#  ['DADELO (DAD)*',
#   'Kupuj',
#   '19,70 zł',
#   '20,00 zł',
#   '1,52%',
#   '15,45 zł',
#   'Trigon DM',
#   '24.07.2023',
#   ''],
#  ['MOBRUK (MBR)',
#   'Kupuj',
#   '317,00 zł',
#   '372,00 zł',
#   '17,35%',
#   '271,50 zł',
#   'BM mBank',
#   '24.07.2023',
#   ''],
#  ['FABRITY (FAB)*',
#   'Trzymaj',
#   '34,00 zł',
#   '37,00 zł',
#   '8,82%',
#   '36,80 zł',
#   'Trigon DM',
#   '24.07.2023',
#   ''],
#  ['VERCOM (VRC)',
#   'Trzymaj',
#   '135,50 zł',
#   '71,70 zł',
#   '-47,08%',
#   '69,80 zł',
#   'DM BOŚ',
#   '24.07.2023',
#   ''],
#  ['DEVELIA (DVL)',
#   'Kupuj',
#   '5,60 zł',
#   '5,50 zł',
#   '-1,79%',
#   '4,81 zł',
#   'Trigon DM',
#   '24.07.2023',
#   ''],
#  ['MILLENNIUM (MIL)',
#   'Kupuj',
#   '8,91 zł',
#   '7,86 zł',
#   '-11,73%',
#   '6,61 zł',
#   'DM BOŚ',
#   '22.07.2023',
#   ''],
#  ['11BIT (11B)',
#   'Kupuj',
#   '642,00 zł',
#   '875,00 zł',
#   '36,29%',
#   '713,00 zł',
#   'DM BDM',
#   '21.07.2023',
#   ''],
#  ['FORTE (FTE)',
#   'Akumuluj',
#   '21,90 zł',
#   '31,00 zł',
#   '41,55%',
#   '28,60 zł',
#   'Noble Securities',
#   '20.07.2023',
#   ''],
#  ['NOVAVISGR (NVG)',
#   'Kupuj',
#   '2,26 zł',
#   '3,89 zł',
#   '72,12%',
#   '1,77 zł',
#   'Erste',
#   '19.07.2023',
#   ''],
#  ['TEXT (TXT)',
#   'Trzymaj',
#   '78,70 zł',
#   '137,50 zł',
#   '74,71%',
#   '148,20 zł',
#   'DM BOŚ',
#   '14.07.2023',
#   ''],
#  ['PKNORLEN (PKN)',
#   'Kupuj',
#   '67,68 zł',
#   '95,50 zł',
#   '41,11%',
#   '65,51 zł',
#   'DM BOŚ',
#   '11.07.2023',
#   ''],
#  ['NEUCA (NEU)',
#   'Kupuj',
#   '927,00 zł',
#   '939,00 zł',
#   '1,29%',
#   '764,00 zł',
#   'DM BDM',
#   '10.07.2023',
#   ''],
#  ['VOXEL (VOX)',
#   'Kupuj',
#   '93,20 zł',
#   '73,80 zł',
#   '-20,82%',
#   '48,40 zł',
#   'East Value Research',
#   '10.07.2023',
#   ''],
#  ['ASSECOBS (ABS)',
#   'Kupuj',
#   '62,20 zł',
#   '44,60 zł',
#   '-28,30%',
#   '38,60 zł',
#   'DM BOŚ',
#   '07.07.2023',
#   ''],
#  ['ANSWEAR (ANR)',
#   'Kupuj',
#   '22,90 zł',
#   '48,00 zł',
#   '109,61%',
#   '36,60 zł',
#   'Noble Securities',
#   '07.07.2023',
#   ''],
#  ['KRUK (KRU)',
#   'Kupuj',
#   '452,00 zł',
#   '440,73 zł',
#   '-2,49%',
#   '412,20 zł',
#   'BM mBank',
#   '05.07.2023',
#   ''],
#  ['TSGAMES (TEN)',
#   'Kupuj',
#   '84,55 zł',
#   '104,00 zł',
#   '23,00%',
#   '79,35 zł',
#   'DM BDM',
#   '05.07.2023',
#   ''],
#  ['CAPTORTX (CTX)',
#   'Akumuluj',
#   '78,60 zł',
#   '183,60 zł',
#   '133,59%',
#   '146,50 zł',
#   'Noble Securities',
#   '05.07.2023',
#   ''],
#  ['DATAWALK (DAT)*',
#   'Kupuj',
#   '65,10 zł',
#   '122,00 zł',
#   '87,40%',
#   '65,30 zł',
#   'DM BOŚ',
#   '05.07.2023',
#   ''],
#  ['OPONEO.PL (OPN)',
#   'Kupuj',
#   '76,20 zł',
#   '51,20 zł',
#   '-32,81%',
#   '43,10 zł',
#   'East Value Research',
#   '04.07.2023',
#   ''],
#  ['WITTCHEN (WTN)',
#   'Akumuluj',
#   '32,05 zł',
#   '39,50 zł',
#   '23,24%',
#   '36,60 zł',
#   'DM Banku BPS',
#   '03.07.2023',
#   ''],
#  ['HANDLOWY (BHW)',
#   'Trzymaj',
#   '109,00 zł',
#   '80,00 zł',
#   '-26,61%',
#   '87,10 zł',
#   'BM mBank',
#   '30.06.2023',
#   ''],
#  ['SNIEZKA (SKA)*',
#   'Kupuj',
#   '89,40 zł',
#   '92,69 zł',
#   '3,68%',
#   '70,40 zł',
#   'Ipopema Securities',
#   '30.06.2023',
#   ''],
#  ['CAPTORTX (CTX)*',
#   'Kupuj',
#   '78,60 zł',
#   '221,00 zł',
#   '181,17%',
#   '148,00 zł',
#   'Trigon DM',
#   '29.06.2023',
#   ''],
#  ['MOLECURE (MOC)*',
#   'Trzymaj',
#   '13,90 zł',
#   '23,20 zł',
#   '66,91%',
#   '21,00 zł',
#   'Ipopema Securities',
#   '29.06.2023',
#   ''],
#  ['SFD (SFD)*',
#   'Trzymaj',
#   '2,19 zł',
#   '4,54 zł',
#   '107,31%',
#   '4,18 zł',
#   'Ipopema Securities',
#   '29.06.2023',
#   ''],
#  ['SYNEKTIK (SNT)*',
#   'Trzymaj',
#   '132,60 zł',
#   '75,00 zł',
#   '-43,44%',
#   '74,40 zł',
#   'Ipopema Securities',
#   '29.06.2023',
#   ''],
#  ['PEP (PEP)',
#   'Kupuj',
#   '64,80 zł',
#   '96,70 zł',
#   '49,23%',
#   '82,70 zł',
#   'Trigon DM',
#   '26.06.2023',
#   ''],
#  ['CYBERFLKS (CBF)*',
#   'Kupuj',
#   '125,00 zł',
#   '88,60 zł',
#   '-29,12%',
#   '68,80 zł',
#   'Trigon DM',
#   '26.06.2023',
#   ''],
#  ['ASSECOSEE (ASE)',
#   'Trzymaj',
#   '51,00 zł',
#   '50,00 zł',
#   '-1,96%',
#   '47,30 zł',
#   'DM BOŚ',
#   '26.06.2023',
#   '']]

# %%
print("\n\nRekomendacje\n") 
print(pd.DataFrame(tabela.tables[0])) #converting table to dataframe
# Out:
# Rekomendacje
#
#                     0         1              2              3  \
# 0              Spółka    Rodzaj  Cena aktualna  Cena docelowa
# 1         PEPCO (PCO)   Trzymaj       22,25 zł       26,50 zł
# 2           LPP (LPP)     Kupuj   16 880,00 zł   23 500,00 zł
# 3       SELVITA (SLV)  Akumuluj       67,30 zł       74,60 zł
# 4      AILLERON (ALL)     Kupuj       17,40 zł       23,10 zł
# ..                ...       ...            ...            ...
# 336        SFD (SFD)*   Trzymaj        2,19 zł        4,54 zł
# 337   SYNEKTIK (SNT)*   Trzymaj      132,60 zł       75,00 zł
# 338         PEP (PEP)     Kupuj       64,80 zł       96,70 zł
# 339  CYBERFLKS (CBF)*     Kupuj      125,00 zł       88,60 zł
# 340   ASSECOSEE (ASE)   Trzymaj       51,00 zł       50,00 zł
#
#                          4                  5                   6           7  \
# 0    Potencjał zmiany ceny  Cena w dniu publ.          Instytucja  Data publ.
# 1                   19,10%           22,35 zł           Trigon DM  25.06.2024
# 2                   39,22%       16 880,00 zł           Trigon DM  24.06.2024
# 3                   10,85%           63,70 zł    Noble Securities  17.06.2024
# 4                   32,76%           17,06 zł    Noble Securities  13.06.2024
# ..                     ...                ...                 ...         ...
# 336                107,31%            4,18 zł  Ipopema Securities  29.06.2023
# 337                -43,44%           74,40 zł  Ipopema Securities  29.06.2023
# 338                 49,23%           82,70 zł           Trigon DM  26.06.2023
# 339                -29,12%           68,80 zł           Trigon DM  26.06.2023
# 340                 -1,96%           47,30 zł              DM BOŚ  26.06.2023
#
#           8
# 0    Raport
# 1
# 2
# 3
# 4
# ..      ...
# 336
# 337
# 338
# 339
# 340
#
# [341 rows x 9 columns]

# %%
rec= pd.DataFrame(tabela.tables[0])

# %%
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.expand_frame_repr', False)  # Prevent line breaks in columns
display(rec)
# Out:
#                     0         1              2              3                      4                  5                   6           7       8
# 0              Spółka    Rodzaj  Cena aktualna  Cena docelowa  Potencjał zmiany ceny  Cena w dniu publ.          Instytucja  Data publ.  Raport
# 1         PEPCO (PCO)   Trzymaj       22,25 zł       26,50 zł                 19,10%           22,35 zł           Trigon DM  25.06.2024
# 2           LPP (LPP)     Kupuj   16 880,00 zł   23 500,00 zł                 39,22%       16 880,00 zł           Trigon DM  24.06.2024
# 3       SELVITA (SLV)  Akumuluj       67,30 zł       74,60 zł                 10,85%           63,70 zł    Noble Securities  17.06.2024
# 4      AILLERON (ALL)     Kupuj       17,40 zł       23,10 zł                 32,76%           17,06 zł    Noble Securities  13.06.2024
# ..                ...       ...            ...            ...                    ...                ...                 ...         ...     ...
# 336        SFD (SFD)*   Trzymaj        2,19 zł        4,54 zł                107,31%            4,18 zł  Ipopema Securities  29.06.2023
# 337   SYNEKTIK (SNT)*   Trzymaj      132,60 zł       75,00 zł                -43,44%           74,40 zł  Ipopema Securities  29.06.2023
# 338         PEP (PEP)     Kupuj       64,80 zł       96,70 zł                 49,23%           82,70 zł           Trigon DM  26.06.2023
# 339  CYBERFLKS (CBF)*     Kupuj      125,00 zł       88,60 zł                -29,12%           68,80 zł           Trigon DM  26.06.2023
# 340   ASSECOSEE (ASE)   Trzymaj       51,00 zł       50,00 zł                 -1,96%           47,30 zł              DM BOŚ  26.06.2023
#
# [341 rows x 9 columns]

# %%
rec.describe()
# Out:
#                 0      1         2         3       4          5       6           7    8
# count         341    341       341       341     341        341     341         341  341
# unique        181     10       147       299     328        313      15         170    2
# top     LPP (LPP)  Kupuj  93,20 zł  65,00 zł  -3,58%  165,00 zł  DM BOŚ  04.10.2023
# freq            8    207        10         4       2          3      82          14  340

# %%
rec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 341 entries, 0 to 340
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       341 non-null    object
#  1   1       341 non-null    object
#  2   2       341 non-null    object
#  3   3       341 non-null    object
#  4   4       341 non-null    object
#  5   5       341 non-null    object
#  6   6       341 non-null    object
#  7   7       341 non-null    object
#  8   8       341 non-null    object
# dtypes: object(9)
# memory usage: 24.1+ KB

# %%
rec.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# 7    object
# 8    object
# dtype: object

# %%
rec.columns = rec.iloc[0]
rec = rec.drop(rec.index[0])
rec.head()
# Out:
# 0          Spółka    Rodzaj Cena aktualna Cena docelowa Potencjał zmiany ceny Cena w dniu publ.        Instytucja  Data publ. Raport
# 1     PEPCO (PCO)   Trzymaj      22,25 zł      26,50 zł                19,10%          22,35 zł         Trigon DM  25.06.2024
# 2       LPP (LPP)     Kupuj  16 880,00 zł  23 500,00 zł                39,22%      16 880,00 zł         Trigon DM  24.06.2024
# 3   SELVITA (SLV)  Akumuluj      67,30 zł      74,60 zł                10,85%          63,70 zł  Noble Securities  17.06.2024
# 4  AILLERON (ALL)     Kupuj      17,40 zł      23,10 zł                32,76%          17,06 zł  Noble Securities  13.06.2024
# 5  RAINBOW (RBW)*     Kupuj     113,00 zł     155,00 zł                37,17%         103,00 zł    BM Banku Pekao  12.06.2024

# %%
#function to clean prices

def clean_prices(rec_clean):
    #dropping the 'zl'
    rec_clean = rec_clean.astype(str).str.replace('zł','')
    #cleaning spaces
    rec_clean= rec_clean.astype(str).str.replace(' ','')
    #changing comma to dot
    rec_clean = rec_clean.astype(str).str.replace(',','.')
    #changing dtype to float, unless empty
    rec_clean = rec_clean.apply(lambda x: float(x) if x else None)
    return rec_clean

# %%
rec['Cena aktualna']= clean_prices(rec['Cena aktualna'])

# %%
print(rec['Cena aktualna'])
# Out:
# 1         22.25
# 2      16880.00
# 3         67.30
# 4         17.40
# 5        113.00
#          ...
# 336        2.19
# 337      132.60
# 338       64.80
# 339      125.00
# 340       51.00
# Name: Cena aktualna, Length: 340, dtype: float64

# %%
rec['Cena docelowa']= clean_prices(rec['Cena docelowa'])
rec['Cena w dniu publ.']= clean_prices(rec['Cena w dniu publ.'])

# %%
rec['Data publ.']= pd.to_datetime(rec['Data publ.'], dayfirst= True) #converting date to pandas datetime object
rec['Potencjał zmiany ceny']= rec['Potencjał zmiany ceny'].astype(str).str.replace('%','').str.replace(',','.').apply(lambda x: float(x) if x else None).apply(lambda x: x/100 if x else None)

# %%
rec.head()
# Out:
# 0          Spółka    Rodzaj  Cena aktualna  Cena docelowa  Potencjał zmiany ceny  Cena w dniu publ.        Instytucja Data publ. Raport
# 1     PEPCO (PCO)   Trzymaj          22.25           26.5                 0.1910              22.35         Trigon DM 2024-06-25
# 2       LPP (LPP)     Kupuj       16880.00        23500.0                 0.3922           16880.00         Trigon DM 2024-06-24
# 3   SELVITA (SLV)  Akumuluj          67.30           74.6                 0.1085              63.70  Noble Securities 2024-06-17
# 4  AILLERON (ALL)     Kupuj          17.40           23.1                 0.3276              17.06  Noble Securities 2024-06-13
# 5  RAINBOW (RBW)*     Kupuj         113.00          155.0                 0.3717             103.00    BM Banku Pekao 2024-06-12

# %%
print(rec)
# Out:
# 0              Spółka    Rodzaj  Cena aktualna  Cena docelowa  Potencjał zmiany ceny  Cena w dniu publ.          Instytucja Data publ. Raport
# 1         PEPCO (PCO)   Trzymaj          22.25          26.50                 0.1910              22.35           Trigon DM 2024-06-25
# 2           LPP (LPP)     Kupuj       16880.00       23500.00                 0.3922           16880.00           Trigon DM 2024-06-24
# 3       SELVITA (SLV)  Akumuluj          67.30          74.60                 0.1085              63.70    Noble Securities 2024-06-17
# 4      AILLERON (ALL)     Kupuj          17.40          23.10                 0.3276              17.06    Noble Securities 2024-06-13
# 5      RAINBOW (RBW)*     Kupuj         113.00         155.00                 0.3717             103.00      BM Banku Pekao 2024-06-12
# ..                ...       ...            ...            ...                    ...                ...                 ...        ...    ...
# 336        SFD (SFD)*   Trzymaj           2.19           4.54                 1.0731               4.18  Ipopema Securities 2023-06-29
# 337   SYNEKTIK (SNT)*   Trzymaj         132.60          75.00                -0.4344              74.40  Ipopema Securities 2023-06-29
# 338         PEP (PEP)     Kupuj          64.80          96.70                 0.4923              82.70           Trigon DM 2023-06-26
# 339  CYBERFLKS (CBF)*     Kupuj         125.00          88.60                -0.2912              68.80           Trigon DM 2023-06-26
# 340   ASSECOSEE (ASE)   Trzymaj          51.00          50.00                -0.0196              47.30              DM BOŚ 2023-06-26
#
# [340 rows x 9 columns]

# %%
rec.to_csv('~/Documents/python/investors-sphere/rec.csv')
